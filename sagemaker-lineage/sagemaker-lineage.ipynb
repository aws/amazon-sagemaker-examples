# %% [markdown]
# # Amazon SageMaker Lineage
# Amazon SageMaker Lineage enables events that happen within SageMaker to be traced via a graph structure.  The data simplifies generating reports, making comparisons, or discovering relationships between events.  For example easily trace both how a model was generated and where the model was deployed.
#
# The lineage graph is created automatically by SageMaker and you can directly create or modify your own graphs.
#
#
# ## Key Concepts
#
# * **Lineage Graph** - A connected graph tracing your machine learning workflow end to end.
# * **Artifacts** - Represents a URI addressable object or data.  Artifacts are typically inputs or outputs to Actions.
# * **Actions**  - Represents an action taken such as a computation, transformation, or job.
# * **Contexts** - Provides a method to logically group other entities.
# * **Associations** - A directed edge in the lineage graph that links two entities.
# * **Lineage Traversal** - Starting from an arbitrary point trace the lineage graph to discover and analyze relationships between steps in your workflow.
# * **Experiments** - Experiment entites (Experiments, Trials, and Trial Components) are also part of the lineage graph and can be associated wtih Artifacts, Actions, or Contexts.

# %% [markdown]
# ## Notebook Overview
#
# This notebook demonstrates how to:
# * Understand the basics of lineage entities.
# * Create and associate lineage entities to track your workflow.
# * Traverse the associations between lineage entities.

# %% [markdown]
# ## Prerequisites
#
# Select the `Python 3 (Data Science)` kernel in SageMaker Studio.

# %%
import boto3
import sagemaker

region = boto3.Session().region_name
sagemaker_session = sagemaker.session.Session()
default_bucket = sagemaker_session.default_bucket()

# %%
from datetime import datetime
from sagemaker.lineage.context import Context
from sagemaker.lineage.action import Action
from sagemaker.lineage.association import Association
from sagemaker.lineage.artifact import Artifact

unique_id = str(int(datetime.now().replace(microsecond=0).timestamp()))

print(f"Unique id is {unique_id}")
# Out:
# Unique id is 1621296503

# %%
# create an example context

# the name must be unique across all other contexts
context_name = f"machine-learning-workflow-{unique_id}"

ml_workflow_context = Context.create(
    context_name=context_name,
    context_type="MLWorkflow",
    source_uri=unique_id,
    # properties services as a method to store metdata on lineage entities in additional to Tags
    properties={"example": "true"},
)

# %%
# list all the contexts

contexts = Context.list(sort_by="CreationTime", sort_order="Descending")

#for ctx in contexts:
    #print(ctx.context_name)
# Out:
# machine-learning-workflow-1621296503
# knn-latency-ivfpq-l2-large-ml-c5-xlarge-1621284171-8667364-1621284172-aws-endpoint
# knn-latency-flat-l2-large-ml-p2-xlarge-1621283417-3186255-1621283418-aws-endpoint
# knn-latency-flat-l2-large-ml-c5-xlarge-1621282649-4973311-1621282650-aws-endpoint
# knn-latency-ivfpq-l2-ml-p2-xlarge-1621281903-0450108-1621281903-aws-endpoint
# knn-latency-ivfpq-l2-ml-c5-xlarge-1621281099-72657-1621281100-aws-endpoint
# ipinsights-210517-1906-004-9bac466d-1621280360-aws-endpoint
# knn-latency-flat-l2-ml-p2-xlarge-1621280354-7989833-1621280355-aws-endpoint
# deepar-electricity-demo-new-features-2021-05-17-19-29-52-873-1621279793-aws-endpoint
# image-classification-2021-05-17-19-28-14-305-1621279694-aws-endpoint
# knn-latency-flat-l2-ml-c5-xlarge-1621279637-596154-1621279638-aws-endpoint
# sagemaker-sklearn-automl-2021-05-17-19-24-09-008-1621279449-aws-endpoint
# tuning-job-1-a855b07ca0b4438e80-018-6059487117-19-22-38-ep-1621279359-aws-endpoint
# inference-pipeline-ep-2021-05-17-19-21-42-1621279303-aws-endpoint
# object-detection-2021-05-17-19-20-27-675-1621279228-aws-endpoint
# ss-notebook-demo-2021-05-17-19-10-29-976-1621278630-aws-endpoint
# sagemaker-clarify-endpoint-1621278583-b49a-1621278583-aws-endpoint
# tensorflow-training-2021-05-17-19-09-30-550-1621278571-aws-endpoint
# automl-churn-17-18-35-27-endpoint-1621278547-aws-endpoint
# sagemaker-clarify-endpoint-1621278526-69f8-1621278527-aws-endpoint
# sagemaker-scikit-learn-2021-05-17-19-06-43-909-1621278404-aws-endpoint
# mnist-multi-2021-05-17-19-05-08-1621278309-aws-endpoint
# cnn-training-job-1621277947-aws-trainin-2021-05-17-19-04-27-562-1621278267-aws-endpoint
# automl-churn-sdk-17-18-35-31-endpoint-1621278206-aws-endpoint
# linear-learner-2021-05-17-19-03-04-989-1621278185-aws-endpoint
# automl-banking-17-18-35-53-endpoint-1621278174-aws-endpoint
# tensorflow-training-2021-05-17-19-01-58-437-1621278118-aws-endpoint
# sagemaker-xgboost-2021-05-17-18-59-55-997-1621277996-aws-endpoint
# randomcutforest-2021-05-17-18-59-37-532-1621277978-aws-endpoint
# DEMO-rl-tic-tac-toe-2021-05-17-18-59-13-710-1621277954-aws-endpoint
# inference-pipeline-ep-2021-05-17-18-59-02-1621277943-aws-endpoint
# tensorflow-training-210517-1847-003-ae9677c4-1621277909-aws-endpoint
# ipinsights-2021-05-17-18-58-24-931-1621277905-aws-endpoint
# deepar-electricity-demo-2021-05-17-18-58-17-888-1621277898-aws-endpoint
# sagemaker-clarify-endpoint-1621277880-600d-1621277880-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-17-18-57-36-982-1621277857-aws-endpoint
# mnist-a-2021-05-17-18-57-06-161-1621277826-aws-endpoint
# sagemaker-clarify-endpoint-1621277822-7cb4-1621277822-aws-endpoint
# mxnet-training-2021-05-17-18-56-19-126-1621277779-aws-endpoint
# mxnet-training-2021-05-17-18-55-46-342-1621277747-aws-endpoint
# tensorflow-training-ml-c5-2021-05-17-18-55-24-875-1621277725-aws-endpoint
# image-classification-2021-05-17-18-55-10-202-1621277710-aws-endpoint
# mme-xgboost-housing-1621277699-aws-endpoint
# linear-learner-2021-05-17-18-54-22-682-1621277663-aws-endpoint
# sagemaker-clarify-endpoint-1621277626-3b58-1621277627-aws-endpoint
# image-classification-2021-05-17-18-53-37-442-1621277618-aws-endpoint
# DEMO-linear-endpoint-202105171853-1621277603-aws-endpoint
# deployed-xgboost-customer-churn-ml-c5-2021-05-17-18-52-49-583-1621277569-aws-endpoint
# tensorflow-inference-eia-2021-05-17-18-51-58-273-1621277518-aws-endpoint
# mxnet-training-2021-05-17-18-51-50-354-1621277511-aws-endpoint
# kmeans-2021-05-17-18-51-35-146-1621277495-aws-endpoint
# knn-ml-m4-xlarge-1621277453-8696084-1621277455-aws-endpoint
# blazingtext-2021-05-17-18-50-52-679-1621277453-aws-endpoint
# tensorflow-inference-ml-c4-2021-05-17-18-50-53-014-1621277453-aws-endpoint
# sagemaker-scikit-learn-2021-05-17-18-50-27-366-1621277427-aws-endpoint
# KMeansEndpoint-2021-05-17-18-50-14-1621277414-aws-endpoint
# resnet152-v2-embedding-2021-05-17-18-48-14-1621277405-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-18-49-42-1621277382-aws-endpoint
# sagemaker-inference-mxnet-2021-05-17-18-49-34-700-1621277374-aws-endpoint
# linear-learner-2021-05-17-18-49-28-471-1621277369-aws-endpoint
# ntm-2021-05-17-18-49-25-638-1621277366-aws-endpoint
# tf-eager-scriptmode-bostonhousing-2021-05-17-18-49-02-071-1621277342-aws-endpoint
# DEMO-kmeans-byom-endpoint-202105171848-1621277331-aws-endpoint
# DEMO-deepar-2021-05-17-18-43-20-082-1621277313-aws-endpoint
# lda-2021-05-17-18-48-30-574-1621277311-aws-endpoint
# sagemaker-inference-mxnet-2021-05-17-18-48-21-625-1621277301-aws-endpoint
# blazingtext-2021-05-17-18-48-19-913-1621277300-aws-endpoint
# linear-learner-2021-05-17-18-48-09-832-1621277290-aws-endpoint
# image-classification-2021-05-17-18-48-07-895-1621277288-aws-endpoint
# pca-2021-05-17-18-48-05-387-1621277286-aws-endpoint
# mxnet-training-ml-c5-2021-05-17-18-47-51-688-1621277271-aws-endpoint
# randomcutforest-2021-05-17-18-47-50-244-1621277270-aws-endpoint
# sagemaker-xgboost-2021-05-17-18-47-41-414-1621277261-aws-endpoint
# blazingtext-2021-05-17-18-47-37-024-1621277257-aws-endpoint
# sagemaker-tensorflow-serving-2021-05-17-18-47-34-159-1621277254-aws-endpoint
# mxnet-training-2021-05-17-18-47-28-229-1621277249-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-18-47-20-1621277240-aws-endpoint
# factorization-machines-2021-05-17-18-47-10-259-1621277231-aws-endpoint
# mxnet-inference-eia-2021-05-17-18-46-57-538-1621277217-aws-endpoint
# mxnet-training-ml-inf1-2021-05-17-18-46-51-430-1621277211-aws-endpoint
# demo-xgboost-customer-churn-2021-05-17-18-46-37-1621277197-aws-endpoint
# tensorflow-inference-eia-2021-05-17-18-46-20-161-1621277180-aws-endpoint
# sagemaker-mxnet-2021-05-17-18-45-41-665-1621277141-aws-endpoint
# tensorflow-training-2021-05-17-18-45-30-842-1621277131-aws-endpoint
# linear-learner-2021-05-17-18-45-04-900-1621277105-aws-endpoint
# sagemaker-xgboost-2021-05-17-18-44-47-281-1621277087-aws-endpoint
# tensorflow-training-2021-05-17-18-44-09-958-1621277050-aws-endpoint
# sagemaker-neo-pytorch-ml-inf1-2021-05-17-18-43-29-145-1621277009-aws-endpoint
# lda-2021-05-17-18-43-25-168-1621277005-aws-endpoint
# blazingtext-2021-05-17-18-43-18-443-1621276998-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-17-18-43-14-077-1621276994-aws-endpoint
# ntm-2021-05-17-18-42-59-998-1621276980-aws-endpoint
# xgboost-2021-05-17-18-42-07-996-1621276928-aws-endpoint
# sagemaker-xgboost-2021-05-17-18-42-02-559-1621276923-aws-endpoint
# DEMO-linear-endpoint-202105171841-1621276911-aws-endpoint
# linear-learner-2021-05-17-18-41-30-445-1621276891-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-18-41-15-1621276876-aws-endpoint
# sagemaker-inference-pytorch-2021-05-17-18-41-16-303-1621276876-aws-endpoint
# DEMO-xgb-churn-model-quality-monitor-2021-05-17-1840-1621276851-aws-endpoint
# sagemaker-xgboost-2021-05-17-18-40-48-739-1621276849-aws-endpoint
# DEMO-xgb-churn-pred-model-monitor-2021-05-17-18-40-48-1621276849-aws-endpoint
# linear-learner-2021-05-17-18-40-43-522-1621276844-aws-endpoint
# DEMO-tf2-california-housing-model-monitor-2021-05-17-18-40-29-1621276829-aws-endpoint
# DEMO-xgb-churn-model-monitor-2021-05-17-1840-1621276826-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-18-40-09-1621276809-aws-endpoint
# tensorflow-inference-2021-05-17-18-40-05-665-1621276805-aws-endpoint
# sagemaker-inference-pytorch-2021-05-17-18-39-28-372-1621276768-aws-endpoint
# DEMO-xgb-churn-pred-2021-05-17-18-38-35-1621276715-aws-endpoint
# mxnet-inference-eia-2021-05-17-18-38-20-489-1621276700-aws-endpoint
# tensorflow-inference-2021-05-17-18-37-06-633-1621276626-aws-endpoint
# tensorflow-inference-2021-05-17-18-36-34-165-1621276594-aws-endpoint
# machine-learning-workflow-1621276537
# knn-latency-ivfpq-l2-large-ml-p2-xlarge-1621217849-9691827-1621217850-aws-endpoint
# knn-latency-ivfpq-l2-large-ml-c5-xlarge-1621217225-0592828-1621217225-aws-endpoint
# sagemaker-clarify-endpoint-1621217160-fe86-1621217161-aws-endpoint
# knn-latency-flat-l2-large-ml-p2-xlarge-1621216469-2738078-1621216469-aws-endpoint
# knn-latency-flat-l2-large-ml-c5-xlarge-1621215696-5302606-1621215697-aws-endpoint
# knn-latency-ivfpq-l2-ml-p2-xlarge-1621214939-5870776-1621214940-aws-endpoint
# sagemaker-clarify-endpoint-1621214420-c606-1621214420-aws-endpoint
# knn-latency-ivfpq-l2-ml-c5-xlarge-1621214315-206628-1621214315-aws-endpoint
# ipinsights-210517-0040-001-9f56e045-1621214009-aws-endpoint
# knn-latency-flat-l2-ml-p2-xlarge-1621213569-55379-1621213570-aws-endpoint
# image-classification-2021-05-17-00-56-49-987-1621213010-aws-endpoint
# inference-pipeline-ep-2021-05-17-00-54-14-1621212854-aws-endpoint
# knn-latency-flat-l2-ml-c5-xlarge-1621212850-3563986-1621212851-aws-endpoint
# object-detection-2021-05-17-00-51-26-879-1621212687-aws-endpoint
# tuning-job-1-a1c3efa2de10449f97-004-bf87e25a17-00-50-29-ep-1621212630-aws-endpoint
# deepar-electricity-demo-new-features-2021-05-17-00-50-01-488-1621212602-aws-endpoint
# tensorflow-training-2021-05-17-00-43-53-707-1621212234-aws-endpoint
# ss-notebook-demo-2021-05-17-00-42-19-635-1621212140-aws-endpoint
# sagemaker-clarify-endpoint-1621212112-a4d6-1621212112-aws-endpoint
# sagemaker-clarify-endpoint-1621212070-449b-1621212071-aws-endpoint
# linear-learner-2021-05-17-00-37-27-268-1621211847-aws-endpoint
# automl-churn-17-00-08-20-endpoint-1621211829-aws-endpoint
# automl-churn-sdk-17-00-08-24-endpoint-1621211807-aws-endpoint
# cnn-training-job-1621210627-aws-trainin-2021-05-17-00-36-42-477-1621211802-aws-endpoint
# mnist-multi-2021-05-17-00-36-38-1621211799-aws-endpoint
# tensorflow-training-2021-05-17-00-35-51-561-1621211752-aws-endpoint
# sagemaker-scikit-learn-2021-05-17-00-35-13-887-1621211714-aws-endpoint
# DEMO-rl-tic-tac-toe-2021-05-17-00-33-34-366-1621211615-aws-endpoint
# ipinsights-2021-05-17-00-33-02-271-1621211582-aws-endpoint
# inference-pipeline-ep-2021-05-17-00-32-31-1621211552-aws-endpoint
# automl-banking-17-00-08-35-endpoint-1621211528-aws-endpoint
# sagemaker-xgboost-2021-05-17-00-32-06-374-1621211527-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-17-00-31-55-223-1621211515-aws-endpoint
# randomcutforest-2021-05-17-00-31-39-475-1621211500-aws-endpoint
# tensorflow-training-210517-0020-002-5c53c9d4-1621211441-aws-endpoint
# sagemaker-clarify-endpoint-1621211395-f03d-1621211396-aws-endpoint
# sagemaker-clarify-endpoint-1621211364-5c65-1621211364-aws-endpoint
# mnist-a-2021-05-17-00-29-06-032-1621211346-aws-endpoint
# mxnet-training-2021-05-17-00-28-54-873-1621211335-aws-endpoint
# mxnet-training-2021-05-17-00-28-38-213-1621211319-aws-endpoint
# tensorflow-training-ml-c5-2021-05-17-00-28-15-535-1621211295-aws-endpoint
# deepar-electricity-demo-2021-05-17-00-27-32-879-1621211253-aws-endpoint
# DEMO-linear-endpoint-202105170027-1621211234-aws-endpoint
# mme-xgboost-housing-1621211193-aws-endpoint
# sagemaker-clarify-endpoint-1621211186-4718-1621211186-aws-endpoint
# image-classification-2021-05-17-00-26-16-566-1621211177-aws-endpoint
# image-classification-2021-05-17-00-26-03-687-1621211164-aws-endpoint
# linear-learner-2021-05-17-00-25-53-985-1621211154-aws-endpoint
# sagemaker-inference-mxnet-2021-05-17-00-24-17-106-1621211057-aws-endpoint
# blazingtext-2021-05-17-00-23-58-253-1621211040-aws-endpoint
# deployed-xgboost-customer-churn-ml-c5-2021-05-17-00-23-57-025-1621211037-aws-endpoint
# kmeans-2021-05-17-00-23-55-274-1621211035-aws-endpoint
# tensorflow-inference-eia-2021-05-17-00-23-20-584-1621211000-aws-endpoint
# tensorflow-inference-ml-c4-2021-05-17-00-23-18-417-1621210998-aws-endpoint
# mxnet-training-2021-05-17-00-23-10-643-1621210991-aws-endpoint
# knn-ml-m4-xlarge-1621210967-8804758-1621210968-aws-endpoint
# KMeansEndpoint-2021-05-17-00-22-29-1621210949-aws-endpoint
# resnet152-v2-embedding-2021-05-17-00-20-36-1621210948-aws-endpoint
# linear-learner-2021-05-17-00-22-20-046-1621210940-aws-endpoint
# sagemaker-scikit-learn-2021-05-17-00-22-10-977-1621210931-aws-endpoint
# tf-eager-scriptmode-bostonhousing-2021-05-17-00-22-07-042-1621210927-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-00-21-56-1621210916-aws-endpoint
# DEMO-kmeans-byom-endpoint-202105170021-1621210908-aws-endpoint
# linear-learner-2021-05-17-00-21-03-756-1621210864-aws-endpoint
# image-classification-2021-05-17-00-20-57-912-1621210858-aws-endpoint
# DEMO-deepar-2021-05-17-00-15-34-236-1621210847-aws-endpoint
# pca-2021-05-17-00-20-45-800-1621210846-aws-endpoint
# sagemaker-tensorflow-serving-2021-05-17-00-20-31-794-1621210832-aws-endpoint
# randomcutforest-2021-05-17-00-20-22-859-1621210823-aws-endpoint
# lda-2021-05-17-00-20-14-441-1621210815-aws-endpoint
# mxnet-training-2021-05-17-00-20-11-471-1621210812-aws-endpoint
# blazingtext-2021-05-17-00-20-10-985-1621210811-aws-endpoint
# ntm-2021-05-17-00-20-03-827-1621210804-aws-endpoint
# factorization-machines-2021-05-17-00-19-55-465-1621210796-aws-endpoint
# blazingtext-2021-05-17-00-19-51-357-1621210791-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-00-19-39-1621210779-aws-endpoint
# sagemaker-xgboost-2021-05-17-00-19-35-215-1621210775-aws-endpoint
# sagemaker-inference-mxnet-2021-05-17-00-19-25-309-1621210765-aws-endpoint
# sagemaker-xgboost-2021-05-17-00-19-18-245-1621210759-aws-endpoint
# mxnet-training-ml-inf1-2021-05-17-00-19-05-706-1621210745-aws-endpoint
# mxnet-training-ml-c5-2021-05-17-00-18-55-035-1621210735-aws-endpoint
# mxnet-inference-eia-2021-05-17-00-18-48-562-1621210728-aws-endpoint
# tensorflow-training-2021-05-17-00-18-20-203-1621210700-aws-endpoint
# tensorflow-inference-eia-2021-05-17-00-18-11-141-1621210691-aws-endpoint
# sagemaker-mxnet-2021-05-17-00-17-58-237-1621210680-aws-endpoint
# demo-xgboost-customer-churn-2021-05-17-00-17-57-1621210678-aws-endpoint
# linear-learner-2021-05-17-00-17-56-816-1621210677-aws-endpoint
# sagemaker-xgboost-2021-05-17-00-16-54-297-1621210614-aws-endpoint
# tensorflow-training-2021-05-17-00-16-35-482-1621210596-aws-endpoint
# ntm-2021-05-17-00-15-57-747-1621210558-aws-endpoint
# blazingtext-2021-05-17-00-15-55-123-1621210555-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-17-00-15-13-621-1621210513-aws-endpoint
# sagemaker-neo-pytorch-ml-inf1-2021-05-17-00-15-08-849-1621210509-aws-endpoint
# DEMO-linear-endpoint-202105170014-1621210488-aws-endpoint
# sagemaker-xgboost-2021-05-17-00-14-17-799-1621210458-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-00-14-07-1621210447-aws-endpoint
# linear-learner-2021-05-17-00-14-00-158-1621210441-aws-endpoint
# sagemaker-xgboost-2021-05-17-00-13-59-706-1621210440-aws-endpoint
# xgboost-2021-05-17-00-13-32-675-1621210413-aws-endpoint
# DEMO-xgb-churn-model-monitor-2021-05-17-0013-1621210413-aws-endpoint
# sagemaker-inference-pytorch-2021-05-17-00-13-31-277-1621210411-aws-endpoint
# DEMO-xgb-churn-pred-model-monitor-2021-05-17-00-13-25-1621210405-aws-endpoint
# lda-2021-05-17-00-13-22-757-1621210403-aws-endpoint
# DEMO-xgb-churn-model-quality-monitor-2021-05-17-0013-1621210392-aws-endpoint
# DEMO-tf2-california-housing-model-monitor-2021-05-17-00-13-05-1621210386-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-17-00-13-01-1621210382-aws-endpoint
# linear-learner-2021-05-17-00-12-50-914-1621210371-aws-endpoint
# tensorflow-inference-2021-05-17-00-12-43-493-1621210363-aws-endpoint
# sagemaker-inference-pytorch-2021-05-17-00-12-29-241-1621210349-aws-endpoint
# DEMO-xgb-churn-pred-2021-05-17-00-11-17-1621210277-aws-endpoint
# mxnet-inference-eia-2021-05-17-00-10-52-595-1621210252-aws-endpoint
# tensorflow-inference-2021-05-17-00-10-03-411-1621210203-aws-endpoint
# tensorflow-inference-2021-05-17-00-09-04-798-1621210145-aws-endpoint
# machine-learning-workflow-1621210112
# knn-latency-ivfpq-l2-large-ml-p2-xlarge-1621131253-958406-1621131254-aws-endpoint
# knn-latency-ivfpq-l2-large-ml-c5-xlarge-1621130637-5398712-1621130638-aws-endpoint
# knn-latency-flat-l2-large-ml-p2-xlarge-1621129887-4991236-1621129888-aws-endpoint
# knn-latency-flat-l2-large-ml-c5-xlarge-1621129182-7435312-1621129183-aws-endpoint
# knn-latency-ivfpq-l2-ml-p2-xlarge-1621128429-4839337-1621128430-aws-endpoint
# sagemaker-clarify-endpoint-1621128125-8b23-1621128125-aws-endpoint
# knn-latency-ivfpq-l2-ml-c5-xlarge-1621127814-187748-1621127814-aws-endpoint
# ipinsights-210516-0037-004-0a3eae67-1621127429-aws-endpoint
# knn-latency-flat-l2-ml-p2-xlarge-1621127067-5812047-1621127068-aws-endpoint
# image-classification-2021-05-16-00-59-32-583-1621126773-aws-endpoint
# sagemaker-sklearn-automl-2021-05-16-00-55-38-700-1621126539-aws-endpoint
# knn-latency-flat-l2-ml-c5-xlarge-1621126418-0064414-1621126418-aws-endpoint
# object-detection-2021-05-16-00-51-43-384-1621126304-aws-endpoint
# inference-pipeline-ep-2021-05-16-00-51-14-1621126275-aws-endpoint
# deepar-electricity-demo-new-features-2021-05-16-00-50-21-895-1621126222-aws-endpoint
# tuning-job-1-00b4f99eed9e4e45a1-015-8196849116-00-46-53-ep-1621126014-aws-endpoint
# tensorflow-training-2021-05-16-00-44-30-434-1621125870-aws-endpoint
# sagemaker-clarify-endpoint-1621125738-0d82-1621125738-aws-endpoint
# ss-notebook-demo-2021-05-16-00-40-27-716-1621125628-aws-endpoint
# sagemaker-clarify-endpoint-1621125599-6ec1-1621125599-aws-endpoint
# tensorflow-training-2021-05-16-00-36-58-452-1621125418-aws-endpoint
# automl-churn-sdk-16-00-07-01-endpoint-1621125319-aws-endpoint
# linear-learner-2021-05-16-00-35-17-474-1621125318-aws-endpoint
# cnn-training-job-1621125023-aws-trainin-2021-05-16-00-35-12-997-1621125313-aws-endpoint
# mnist-multi-2021-05-16-00-35-11-1621125312-aws-endpoint
# sagemaker-scikit-learn-2021-05-16-00-34-46-358-1621125286-aws-endpoint
# automl-churn-16-00-07-09-endpoint-1621125238-aws-endpoint
# sagemaker-xgboost-2021-05-16-00-31-45-926-1621125106-aws-endpoint
# DEMO-rl-tic-tac-toe-2021-05-16-00-31-00-386-1621125061-aws-endpoint
# tensorflow-training-210516-0018-002-c6472219-1621125036-aws-endpoint
# inference-pipeline-ep-2021-05-16-00-30-14-1621125015-aws-endpoint
# randomcutforest-2021-05-16-00-30-09-738-1621125010-aws-endpoint
# ipinsights-2021-05-16-00-30-07-110-1621125007-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-16-00-29-55-972-1621124996-aws-endpoint
# automl-banking-16-00-06-54-endpoint-1621124974-aws-endpoint
# sagemaker-clarify-endpoint-1621124965-8b59-1621124965-aws-endpoint
# mnist-a-2021-05-16-00-28-39-368-1621124919-aws-endpoint
# mxnet-training-2021-05-16-00-28-03-553-1621124884-aws-endpoint
# sagemaker-clarify-endpoint-1621124877-2e5d-1621124877-aws-endpoint
# tensorflow-training-ml-c5-2021-05-16-00-27-30-743-1621124850-aws-endpoint
# mxnet-training-2021-05-16-00-26-50-223-1621124811-aws-endpoint
# DEMO-linear-endpoint-202105160026-1621124782-aws-endpoint
# linear-learner-2021-05-16-00-26-08-809-1621124769-aws-endpoint
# deepar-electricity-demo-2021-05-16-00-25-44-607-1621124745-aws-endpoint
# image-classification-2021-05-16-00-25-34-697-1621124735-aws-endpoint
# mme-xgboost-housing-1621124722-aws-endpoint
# image-classification-2021-05-16-00-24-58-211-1621124698-aws-endpoint
# deployed-xgboost-customer-churn-ml-c5-2021-05-16-00-24-15-759-1621124656-aws-endpoint
# sagemaker-clarify-endpoint-1621124642-d12c-1621124642-aws-endpoint
# KMeansEndpoint-2021-05-16-00-23-40-1621124620-aws-endpoint
# tensorflow-inference-eia-2021-05-16-00-23-19-427-1621124599-aws-endpoint
# kmeans-2021-05-16-00-22-24-704-1621124545-aws-endpoint
# mxnet-training-2021-05-16-00-22-21-974-1621124542-aws-endpoint
# blazingtext-2021-05-16-00-22-14-957-1621124535-aws-endpoint
# tensorflow-inference-ml-c4-2021-05-16-00-22-02-668-1621124522-aws-endpoint
# sagemaker-scikit-learn-2021-05-16-00-21-49-012-1621124509-aws-endpoint
# knn-ml-m4-xlarge-1621124504-3004103-1621124504-aws-endpoint
# resnet152-v2-embedding-2021-05-16-00-19-40-1621124491-aws-endpoint
# tf-eager-scriptmode-bostonhousing-2021-05-16-00-21-29-725-1621124490-aws-endpoint
# linear-learner-2021-05-16-00-21-24-880-1621124485-aws-endpoint
# sagemaker-inference-mxnet-2021-05-16-00-21-16-705-1621124477-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-16-00-21-07-1621124467-aws-endpoint
# DEMO-kmeans-byom-endpoint-202105160020-1621124433-aws-endpoint
# blazingtext-2021-05-16-00-20-01-264-1621124401-aws-endpoint
# linear-learner-2021-05-16-00-19-41-896-1621124382-aws-endpoint
# pca-2021-05-16-00-19-40-598-1621124381-aws-endpoint
# ntm-2021-05-16-00-19-33-658-1621124374-aws-endpoint
# image-classification-2021-05-16-00-19-32-572-1621124373-aws-endpoint
# factorization-machines-2021-05-16-00-19-26-489-1621124367-aws-endpoint
# sagemaker-tensorflow-serving-2021-05-16-00-19-25-289-1621124365-aws-endpoint
# randomcutforest-2021-05-16-00-19-22-880-1621124363-aws-endpoint
# lda-2021-05-16-00-19-09-754-1621124350-aws-endpoint
# DEMO-deepar-2021-05-16-00-14-25-598-1621124348-aws-endpoint
# sagemaker-xgboost-2021-05-16-00-19-06-132-1621124346-aws-endpoint
# blazingtext-2021-05-16-00-18-57-463-1621124338-aws-endpoint
# mxnet-training-2021-05-16-00-18-51-413-1621124332-aws-endpoint
# sagemaker-inference-mxnet-2021-05-16-00-18-17-811-1621124298-aws-endpoint
# mxnet-training-ml-inf1-2021-05-16-00-18-17-334-1621124297-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-16-00-18-10-1621124290-aws-endpoint
# mxnet-inference-eia-2021-05-16-00-18-09-081-1621124289-aws-endpoint
# sagemaker-xgboost-2021-05-16-00-17-59-587-1621124279-aws-endpoint
# mxnet-training-ml-c5-2021-05-16-00-17-46-939-1621124267-aws-endpoint
# tensorflow-inference-eia-2021-05-16-00-17-31-267-1621124251-aws-endpoint
# sagemaker-mxnet-2021-05-16-00-17-16-934-1621124237-aws-endpoint
# tensorflow-training-2021-05-16-00-17-05-534-1621124226-aws-endpoint
# demo-xgboost-customer-churn-2021-05-16-00-17-04-1621124224-aws-endpoint
# linear-learner-2021-05-16-00-16-17-766-1621124178-aws-endpoint
# sagemaker-xgboost-2021-05-16-00-16-13-640-1621124174-aws-endpoint
# blazingtext-2021-05-16-00-15-14-701-1621124114-aws-endpoint
# ntm-2021-05-16-00-14-53-816-1621124097-aws-endpoint
# tensorflow-training-2021-05-16-00-14-52-431-1621124092-aws-endpoint
# sagemaker-neo-pytorch-ml-inf1-2021-05-16-00-14-03-449-1621124043-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-16-00-13-43-429-1621124023-aws-endpoint
# linear-learner-2021-05-16-00-13-16-309-1621123996-aws-endpoint
# sagemaker-xgboost-2021-05-16-00-13-08-683-1621123989-aws-endpoint
# lda-2021-05-16-00-13-00-728-1621123981-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-16-00-12-56-1621123976-aws-endpoint
# sagemaker-inference-pytorch-2021-05-16-00-12-45-175-1621123965-aws-endpoint
# sagemaker-xgboost-2021-05-16-00-12-35-286-1621123956-aws-endpoint
# DEMO-xgb-churn-pred-model-monitor-2021-05-16-00-12-30-1621123950-aws-endpoint
# DEMO-xgb-churn-model-quality-monitor-2021-05-16-0012-1621123949-aws-endpoint
# xgboost-2021-05-16-00-12-27-194-1621123947-aws-endpoint
# DEMO-XGBoostEndpoint-2021-05-16-00-12-09-1621123929-aws-endpoint
# DEMO-tf2-california-housing-model-monitor-2021-05-16-00-12-05-1621123926-aws-endpoint
# DEMO-xgb-churn-model-monitor-2021-05-16-0012-1621123922-aws-endpoint
# tensorflow-inference-2021-05-16-00-11-28-917-1621123889-aws-endpoint
# sagemaker-inference-pytorch-2021-05-16-00-11-26-672-1621123886-aws-endpoint
# DEMO-linear-endpoint-202105160011-1621123883-aws-endpoint
# linear-learner-2021-05-16-00-11-14-171-1621123874-aws-endpoint
# DEMO-xgb-churn-pred-2021-05-16-00-09-54-1621123794-aws-endpoint
# mxnet-inference-eia-2021-05-16-00-09-36-296-1621123776-aws-endpoint
# tensorflow-inference-2021-05-16-00-08-41-781-1621123722-aws-endpoint
# tensorflow-inference-2021-05-16-00-08-05-606-1621123685-aws-endpoint
# machine-learning-workflow-1621123638
# sagemaker-clarify-endpoint-1621044841-a51d-1621044842-aws-endpoint
# knn-latency-ivfpq-l2-large-ml-c5-xlarge-1621044607-710116-1621044608-aws-endpoint
# knn-latency-flat-l2-large-ml-p2-xlarge-1621043856-408266-1621043857-aws-endpoint
# knn-latency-flat-l2-large-ml-c5-xlarge-1621043087-2372556-1621043087-aws-endpoint
# knn-latency-ivfpq-l2-ml-p2-xlarge-1621042339-3293931-1621042340-aws-endpoint
# knn-latency-ivfpq-l2-ml-c5-xlarge-1621041660-4103913-1621041661-aws-endpoint
# sagemaker-clarify-endpoint-1621041540-c132-1621041540-aws-endpoint
# ipinsights-210515-0039-004-a703a828-1621041298-aws-endpoint
# knn-latency-flat-l2-ml-p2-xlarge-1621040850-0026317-1621040850-aws-endpoint
# image-classification-2021-05-15-00-59-23-330-1621040364-aws-endpoint
# knn-latency-flat-l2-ml-c5-xlarge-1621040192-7922373-1621040193-aws-endpoint
# inference-pipeline-ep-2021-05-15-00-54-33-1621040074-aws-endpoint
# sagemaker-sklearn-automl-2021-05-15-00-52-05-064-1621039926-aws-endpoint
# object-detection-2021-05-15-00-50-59-845-1621039860-aws-endpoint
# deepar-electricity-demo-new-features-2021-05-15-00-50-13-973-1621039814-aws-endpoint
# tuning-job-1-6fbd17a3e2de4bdc94-005-34cf45ed15-00-50-00-ep-1621039801-aws-endpoint
# tensorflow-training-2021-05-15-00-42-59-959-1621039380-aws-endpoint
# ss-notebook-demo-2021-05-15-00-42-06-398-1621039327-aws-endpoint
# sagemaker-clarify-endpoint-1621039286-5e7a-1621039287-aws-endpoint
# sagemaker-clarify-endpoint-1621039282-c260-1621039283-aws-endpoint
# linear-learner-2021-05-15-00-36-07-268-1621038967-aws-endpoint
# sagemaker-scikit-learn-2021-05-15-00-35-55-468-1621038955-aws-endpoint
# tensorflow-training-2021-05-15-00-35-27-888-1621038928-aws-endpoint
# cnn-training-job-1621037506-aws-trainin-2021-05-15-00-35-15-794-1621038916-aws-endpoint
# automl-churn-sdk-15-00-07-01-endpoint-1621038910-aws-endpoint
# mnist-multi-2021-05-15-00-34-54-1621038895-aws-endpoint
# automl-churn-15-00-06-49-endpoint-1621038874-aws-endpoint
# randomcutforest-2021-05-15-00-32-49-894-1621038770-aws-endpoint
# ipinsights-2021-05-15-00-31-57-205-1621038717-aws-endpoint
# inference-pipeline-ep-2021-05-15-00-31-49-1621038710-aws-endpoint
# DEMO-rl-tic-tac-toe-2021-05-15-00-31-06-348-1621038667-aws-endpoint
# automl-banking-15-00-07-32-endpoint-1621038666-aws-endpoint
# sagemaker-xgboost-2021-05-15-00-30-57-625-1621038658-aws-endpoint
# sagemaker-inference-pytorch-ml-c5-2021-05-15-00-30-07-768-1621038608-aws-endpoint
# tensorflow-training-210515-0018-002-18bcf510-1621038607-aws-endpoint
# sagemaker-clarify-endpoint-1621038551-4d36-1621038551-aws-endpoint
# sagemaker-clarify-endpoint-1621038547-17e7-1621038547-aws-endpoint
# mnist-a-2021-05-15-00-28-22-450-1621038502-aws-endpoint
# tensorflow-training-ml-c5-2021-05-15-00-28-14-273-1621038494-aws-endpoint
# mxnet-training-2021-05-15-00-27-59-579-1621038480-aws-endpoint
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-4-79c590f33fe8> in <module>
#       3 contexts = Context.list(sort_by="CreationTime", sort_order="Descending")
#       4
# ----> 5 for ctx in contexts:
#       6     print(ctx.context_name)
#
# /usr/local/lib/python3.7/site-packages/sagemaker/apiutils/_base_types.py in _list(cls, boto_list_method, list_item_factory, boto_list_items_name, boto_next_token_name, sagemaker_session, **kwargs)
#     137                     list_request_kwargs[boto_next_token_name] = next_token
#     138                 list_method = getattr(sagemaker_client, boto_list_method)
# --> 139                 list_method_response = list_method(**list_request_kwargs)
#     140                 list_items = list_method_response.get(boto_list_items_name, [])
#     141                 next_token = list_method_response.get(boto_next_token_name)
#
# /usr/local/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# /usr/local/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (ThrottlingException) when calling the ListContexts operation (reached max retries: 4): Rate exceeded

# %%
# create an example action and associate it with the context

model_build_action = Action.create(
    action_name=f"model-build-step-{unique_id}",
    action_type="ModelBuild",
    source_uri=unique_id,
    properties={"Example": "Metadata"},
)

# %%
# Association Type can be Produced|DerivedFrom|AssociatedWith|ContributedTo
context_action_association = Association.create(
    source_arn=ml_workflow_context.context_arn,
    destination_arn=model_build_action.action_arn,
    association_type="AssociatedWith",
)

# %%
# now the Action and Context are associated:
incoming_associations_to_action = Association.list(destination_arn=model_build_action.action_arn)
for association in incoming_associations_to_action:
    print(
        f"{model_build_action.action_name} has an incoming association from {association.source_name}"
    )

outgoing_associations_from_context = Association.list(source_arn=ml_workflow_context.context_arn)
for association in outgoing_associations_from_context:
    print(
        f"{ml_workflow_context.context_name} has an outgoing association to {association.destination_name}"
    )

# %%
# create an artifact representing inputs to the model building action
input_test_images = Artifact.create(
    artifact_name="mnist-test-images",
    artifact_type="TestData",
    source_types=[{"SourceIdType": "Custom", "Value": unique_id}],
    source_uri="https://sagemaker-sample-files.s3.amazonaws.com/datasets/image/MNIST/t10k-images-idx3-ubyte.gz",
)

input_test_labels = Artifact.create(
    artifact_name="mnist-test-labels",
    artifact_type="TestLabels",
    source_types=[{"SourceIdType": "Custom", "Value": unique_id}],
    source_uri="https://sagemaker-sample-files.s3.amazonaws.com/datasets/image/MNIST/t10k-labels-idx1-ubyte.gz",
)

# %%
# create an artifact representing a trained model
output_model = Artifact.create(
    artifact_name="mnist-model",
    artifact_type="Model",
    source_types=[{"SourceIdType": "Custom", "Value": unique_id}],
    source_uri="s3://sagemaker-sample-files.s3.amazonaws.com/datasets/image/MNIST/model/tensorflow-training-2020-11-20-23-57-13-077/model.tar.gz",
)

# %%
# associate the data set artifact with an incoming association to the example action
Association.create(
    source_arn=input_test_images.artifact_arn, destination_arn=model_build_action.action_arn
)
Association.create(
    source_arn=input_test_labels.artifact_arn, destination_arn=model_build_action.action_arn
)

# %%
# associate the example action with an outgoing association to the model artifact
Association.create(
    source_arn=model_build_action.action_arn, destination_arn=output_model.artifact_arn
)

# %% [markdown]
# ## Cleanup

# %%
def delete_associations(arn):
    # delete incoming associations
    incoming_associations = Association.list(destination_arn=arn)
    for summary in incoming_associations:
        assct = Association(
            source_arn=summary.source_arn,
            destination_arn=summary.destination_arn,
            sagemaker_session=sagemaker_session,
        )
        assct.delete()

    # delete outgoing associations
    outgoing_associations = Association.list(source_arn=arn)
    for summary in outgoing_associations:
        assct = Association(
            source_arn=summary.source_arn,
            destination_arn=summary.destination_arn,
            sagemaker_session=sagemaker_session,
        )
        assct.delete()


def delete_lineage_data():
    for summary in Context.list():
        print(f"Deleting context {summary.context_name}")
        delete_associations(summary.context_arn)
        ctx = Context(context_name=summary.context_name, sagemaker_session=sagemaker_session)
        ctx.delete()

    for summary in Action.list():
        print(f"Deleting action {summary.action_name}")
        delete_associations(summary.action_arn)
        actn = Action(action_name=summary.action_name, sagemaker_session=sagemaker_session)
        actn.delete()

    for summary in Artifact.list():
        print(f"Deleting artifact {summary.artifact_arn} {summary.artifact_name}")
        delete_associations(summary.artifact_arn)
        artfct = Artifact(artifact_arn=summary.artifact_arn, sagemaker_session=sagemaker_session)
        artfct.delete()


delete_lineage_data()

# %% [markdown]
# ## Caveats
#
# * Associations cannot be created between two experiment entities. For example between an Experiment and Trial.
# * Associations can only be created between the following resources: Experiment, Trial, Trial Component, Action, Artifact, or Context.
# * The maximum number of manually created lineage entities are:
#   * Artifacts: 6000
#   * Contexts: 500
#   * Actions: 3000
#   * Associations: 6000
# * There is no limit on the number of lineage entities created automatically by SageMaker.

# %% [markdown]
# ## Contact
#
# Submit any questions or issues to https://github.com/aws/sagemaker-experiments/issues or mention @aws/sagemakerexperimentsadmin

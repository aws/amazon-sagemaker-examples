# %% [markdown]
# # Fairness and Explainability with SageMaker Clarify - Spark Distributed Processing

# %% [markdown]
# ## Runtime
#
# This notebook takes approximately 30 minutes to run.
#
# ## Contents
# 1. [Overview](#Overview)
# 1. [Prerequisites and Data](#Prerequisites-and-Data)
#     1. [Import Libraries](#Import-Libraries)
#     1. [Set Configurations](#Set-Configurations)
#     1. [Download data](#Download-data)
#     1. [Loading the data: Adult Dataset](#Loading-the-data:-Adult-Dataset)
#     1. [Data inspection](#Data-inspection)
#     1. [Encode and Upload the Dataset](#Encode-and-Upload-the-Dataset)
# 1. [Train and Deploy XGBoost Model](#Train-XGBoost-Model)
#     1. [Train Model](#Train-Model)
#     1. [Create Model](#Create-Model)
# 1. [Amazon SageMaker Clarify](#Amazon-SageMaker-Clarify)
#     1. [Detecting Bias](#Detecting-Bias)
#         1. [Writing DataConfig](#Writing-DataConfig)
#         1. [Writing ModelConfig](#Writing-ModelConfig)
#         1. [Writing ModelPredictedLabelConfig](#Writing-ModelPredictedLabelConfig)
#         1. [Writing BiasConfig](#Writing-BiasConfig)
#         1. [Pre-training Bias](#Pre-training-Bias)
#         1. [Post-training Bias](#Post-training-Bias)
#         1. [Viewing the Bias Report](#Viewing-the-Bias-Report)
#     1. [Explaining Predictions](#Explaining-Predictions)
#         1. [Viewing the Explainability Report](#Viewing-the-Explainability-Report)
#         1. [Analysis of local explanations](#Analysis-of-local-explanations)
#         1. [Visualize local SHAP values](#Visualize-local-SHAP-values)
# 1. [Clean Up](#Clean-Up)
#
# ## Overview
# Amazon SageMaker Clarify helps improve your machine learning models by detecting potential bias and helping explain how these models make predictions. The fairness and explainability functionality provided by SageMaker Clarify takes a step towards enabling AWS customers to build trustworthy and understandable machine learning models. The product comes with the tools to help you with the following tasks.
#
# * Measure biases that can occur during each stage of the ML lifecycle (data collection, model training and tuning, and monitoring of ML models deployed for inference).
# * Generate model governance reports targeting risk and compliance teams and external regulators.
# * Provide explanations of the data, models, and monitoring used to assess predictions.
#
# This sample notebook walks you through:
# 1. Key terms and concepts needed to understand SageMaker Clarify
# 1. Measuring the pre-training bias of a dataset and post-training bias of a model
# 1. Explaining the importance of the various input features on the model's decision
# 1. Accessing the reports through SageMaker Studio if you have an instance set up.
#
# In doing so, the notebook first trains a [SageMaker XGBoost](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost.html) model using training dataset, then use [Amazon SageMaker Python SDK](https://sagemaker.readthedocs.io/en/stable/) to launch SageMaker Clarify jobs to analyze an example dataset in CSV format. This notebook specifically showcases how to use Spark distributed processing for executing clarify jobs.

# %% [markdown]
# ## Prerequisites and Data
# ### Import Libraries

# %%
from sagemaker import session, get_execution_role
from io import StringIO
from s3fs import S3FileSystem
import sagemaker
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import boto3

# %% [markdown]
# ### Set Configurations

# %%
# Initialize sagemaker session
sagemaker_session = session.Session()

region = sagemaker_session.boto_region_name
print(f"Region: {region}")

role = get_execution_role()
print(f"Role: {role}")

bucket = sagemaker_session.default_bucket()

prefix = "sagemaker/DEMO-sagemaker-clarify"
# Out:
# Region: us-west-2
# Role: arn:aws:iam::000000000000:role/service-role/AmazonSageMaker-ExecutionRole-20220304T121686

# %% [markdown]
# ### Download data
# Data Source: [https://archive.ics.uci.edu/ml/machine-learning-databases/adult/](https://archive.ics.uci.edu/ml/machine-learning-databases/adult/)
#
# Let's __download__ the data and save it in the local folder with the name adult.data and adult.test from UCI repository$^{[2]}$.
#
# $^{[2]}$Dua Dheeru, and Efi Karra Taniskidou. "[UCI Machine Learning Repository](http://archive.ics.uci.edu/ml)". Irvine, CA: University of California, School of Information and Computer Science (2017).

# %%
from sagemaker.s3 import S3Downloader

adult_columns = [
    "Age",
    "Workclass",
    "fnlwgt",
    "Education",
    "Education-Num",
    "Marital Status",
    "Occupation",
    "Relationship",
    "Ethnic group",
    "Sex",
    "Capital Gain",
    "Capital Loss",
    "Hours per week",
    "Country",
    "Target",
]
if not os.path.isfile("adult.data"):
    S3Downloader.download(
        s3_uri="s3://{}/{}".format(
            "sagemaker-sample-files", "datasets/tabular/uci_adult/adult.data"
        ),
        local_path="./",
        sagemaker_session=sagemaker_session,
    )
    print("adult.data saved!")
else:
    print("adult.data already on disk.")

if not os.path.isfile("adult.test"):
    S3Downloader.download(
        s3_uri="s3://{}/{}".format(
            "sagemaker-sample-files", "datasets/tabular/uci_adult/adult.test"
        ),
        local_path="./",
        sagemaker_session=sagemaker_session,
    )
    print("adult.test saved!")
else:
    print("adult.test already on disk.")
# Out:
# adult.data saved!
# adult.test saved!

# %% [markdown]
# ### Loading the data: Adult Dataset
# From the UCI repository of machine learning datasets, this database contains 14 features concerning demographic characteristics of 45,222 rows (32,561 for training and 12,661 for testing). The task is to predict whether a person has a yearly income that is more or less than $50,000.
#
# Here are the features and their possible values:
# 1. **Age**: continuous.
# 1. **Workclass**: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# 1. **Fnlwgt**: continuous (the number of people the census takers believe that observation represents).
# 1. **Education**: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# 1. **Education-num**: continuous.
# 1. **Marital-status**: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# 1. **Occupation**: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# 1. **Relationship**: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# 1. **Ethnic group**: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# 1. **Sex**: Female, Male.
#     * **Note**: this data is extracted from the 1994 Census and enforces a binary option on Sex
# 1. **Capital-gain**: continuous.
# 1. **Capital-loss**: continuous.
# 1. **Hours-per-week**: continuous.
# 1. **Native-country**: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
#
# Next, we specify our binary prediction task:
# 15. **Target**: <=50,000, >$50,000.

# %%
training_data = pd.read_csv(
    "adult.data", names=adult_columns, sep=r"\s*,\s*", engine="python", na_values="?"
).dropna()

testing_data = pd.read_csv(
    "adult.test", names=adult_columns, sep=r"\s*,\s*", engine="python", na_values="?", skiprows=1
).dropna()

training_data.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education-Num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        Marital Status         Occupation   Relationship Ethnic group     Sex  \
# 0       Never-married       Adm-clerical  Not-in-family        White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband        White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family        White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband        Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife        Black  Female
#
#    Capital Gain  Capital Loss  Hours per week        Country Target
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# ### Data inspection
# Plotting histograms for the distribution of the different features is a good way to visualize the data. Let's plot a few of the features that can be considered _sensitive_.
# Let's take a look specifically at the Sex feature of a census respondent. In the first plot we see that there are fewer Female respondents as a whole but especially in the positive outcomes, where they form ~$\frac{1}{7}$th of respondents.

# %%
# %matplotlib inline
training_data["Sex"].value_counts().sort_values().plot(kind="bar", title="Counts of Sex", rot=0)

# %%
training_data["Sex"].where(training_data["Target"] == ">50K").value_counts().sort_values().plot(
    kind="bar", title="Counts of Sex earning >$50K", rot=0
)

# %% [markdown]
# ### Encode and Upload the Dataset
# Here we encode the training and test data. Encoding input data is not necessary for SageMaker Clarify, but is necessary for the model.

# %%
from sklearn import preprocessing


def number_encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            #  print('Column:', column, result[column])
            result[column] = encoders[column].fit_transform(result[column].fillna("None"))
    return result, encoders


training_data = pd.concat([training_data["Target"], training_data.drop(["Target"], axis=1)], axis=1)
training_data, _ = number_encode_features(training_data)
training_data.to_csv("train_data.csv", index=False, header=False)

testing_data, _ = number_encode_features(testing_data)
test_features = testing_data.drop(["Target"], axis=1)
test_target = testing_data["Target"]
test_features.to_csv("test_features.csv", index=False, header=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# A quick note about our encoding: the "Female" Sex value has been encoded as 0 and "Male" as 1.

# %%
training_data.head()
# Out:
#    Target  Age  Workclass  fnlwgt  Education  Education-Num  Marital Status  \
# 0       0   39          5   77516          9             13               4
# 1       0   50          4   83311          9             13               2
# 2       0   38          2  215646         11              9               0
# 3       0   53          2  234721          1              7               2
# 4       0   28          2  338409          9             13               2
#
#    Occupation  Relationship  Ethnic group  Sex  Capital Gain  Capital Loss  \
# 0           0             1             4    1          2174             0
# 1           3             0             4    1             0             0
# 2           5             1             4    1             0             0
# 3           5             0             2    1             0             0
# 4           9             5             2    0             0             0
#
#    Hours per week  Country
# 0              40       38
# 1              13       38
# 2              40       38
# 3              40       38
# 4              40        4

# %% [markdown]
# Lastly, let's upload the data to S3

# %%
from sagemaker.s3 import S3Uploader
from sagemaker.inputs import TrainingInput

train_uri = S3Uploader.upload("train_data.csv", "s3://{}/{}".format(bucket, prefix))
train_input = TrainingInput(train_uri, content_type="csv")
test_uri = S3Uploader.upload("test_features.csv", "s3://{}/{}".format(bucket, prefix))

# %% [markdown]
# ### Train XGBoost Model
# #### Train Model
# Since our focus is on understanding how to use SageMaker Clarify, we keep it simple by using a standard XGBoost model.

# %%
from sagemaker.image_uris import retrieve
from sagemaker.estimator import Estimator

container = retrieve("xgboost", region, version="1.2-1")
xgb = Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    disable_profiler=True,
    sagemaker_session=sagemaker_session,
)

xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective="binary:logistic",
    num_round=800,
)

xgb.fit({"train": train_input}, logs=False)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-02-07-03-49-15-216
# 2023-02-07 03:49:15 Starting - Starting the training job..
# 2023-02-07 03:49:29 Starting - Preparing the instances for training..........
# 2023-02-07 03:50:24 Downloading - Downloading input data....
# 2023-02-07 03:50:49 Training - Downloading the training image.....
# 2023-02-07 03:51:19 Training - Training image download completed. Training in progress......
# 2023-02-07 03:51:50 Uploading - Uploading generated training model.
# 2023-02-07 03:52:01 Completed - Training job completed

# %% [markdown]
# #### Deploy Model
# Here we create the SageMaker model.

# %%
from datetime import datetime

model_name = "DEMO-clarify-model-{}".format(datetime.now().strftime("%d-%m-%Y-%H-%M-%S"))
model = xgb.create_model(name=model_name)
container_def = model.prepare_container_def()
sagemaker_session.create_model(model_name, role, container_def)
# Out:
# INFO:sagemaker:Creating model with name: DEMO-clarify-model-07-02-2023-03-52-02
# 'DEMO-clarify-model-07-02-2023-03-52-02'

# %% [markdown]
# ## Amazon SageMaker Clarify
# With your model set up, it's time to explore SageMaker Clarify. For a general overview of how SageMaker Clarify processing jobs work, refer [the provided link](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-processing-job-configure-how-it-works.html).
#
# When working with large datasets, you can use the Spark processing capabilities of SageMaker Clarify to enable your Clarify processing jobs to run faster. To use Spark processing for Clarify jobs, set the instance count to a number greater than one. Clarify uses Spark distributed computing when there is more than one instance per Clarify processor.

# %%
from sagemaker import clarify

# Initialize a SageMakerClarifyProcessor to compute bias metrics and model explanations with instance_count > 1
clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=2, instance_type="ml.m5.xlarge", sagemaker_session=sagemaker_session
)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.0.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %% [markdown]
# ### Detecting Bias
# SageMaker Clarify helps you detect possible [pre-training](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-detect-data-bias.html) and [post-training](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-detect-post-training-bias.html) biases using a variety of metrics.
#
# #### Writing DataConfig
# A [`DataConfig`](https://sagemaker.readthedocs.io/en/stable/api/training/processing.html#sagemaker.clarify.DataConfig) object communicates some basic information about data I/O to SageMaker Clarify. For our example here we provide the below information:
# * `s3_data_input_path`: S3 URI of the train dataset we uploaded above
# * `s3_output_path`: S3 URI at which our output report will be uploaded
# * `label`: Specifies the ground truth label, which is also known as observed label or target attribute. It is used for many bias metrics. In this example, the `Target` column has the ground truth label.
# * `headers`: The list of column names in the dataset
# * `dataset_type`: specifies the format of your dataset, for this example as we are using CSV dataset this will be `text/csv`

# %%
bias_report_output_path = "s3://{}/{}/clarify-bias".format(bucket, prefix)
bias_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=bias_report_output_path,
    label="Target",
    headers=training_data.columns.to_list(),
    dataset_type="text/csv",
)

# %% [markdown]
# #### Writing ModelConfig
# A [`ModelConfig`](https://sagemaker.readthedocs.io/en/stable/api/training/processing.html#sagemaker.clarify.ModelConfig) object communicates information about your trained model. To avoid additional traffic to the production models, SageMaker Clarify sets up and tears down a dedicated endpoint when processing. For our example here we provide the below information:
# * `model_name`: name of the concerned model, using name of the xgboost model trained earlier
# * `instance_type` and `initial_instance_count` specify your preferred instance type and instance count used to run your model on during SageMaker Clarify's processing. Since we used two instances for the ClarifyProcessingJob, we recommend that you also increase the number of instances in the model configuration. This is to prevent the processing instances from being bottlenecked by the shadow endpoint.
# * `accept_type` denotes the endpoint response payload format, and `content_type` denotes the payload format of request to the endpoint. As per the example model we created above both of these will be `text/csv`.

# %%
model_config = clarify.ModelConfig(
    model_name=model_name,
    instance_type="ml.m5.xlarge",
    instance_count=2,
    accept_type="text/csv",
    content_type="text/csv",
)

# %% [markdown]
# #### Writing ModelPredictedLabelConfig
# A [`ModelPredictedLabelConfig`](https://sagemaker.readthedocs.io/en/stable/api/training/processing.html#sagemaker.clarify.ModelPredictedLabelConfig) provides information on the format of your predictions. XGBoost model outputs probabilities of samples, so SageMaker Clarify invokes the endpoint then uses `probability_threshold` to convert the probability to binary labels for bias analysis. Prediction above the threshold is interpreted as label value `1` and below or equal as label value `0`.

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %% [markdown]
# #### Writing BiasConfig
# [`BiasConfig`](https://sagemaker.readthedocs.io/en/stable/api/training/processing.html#sagemaker.clarify.BiasConfig) contains configuration values for detecting bias using a clarify container.

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1], facet_name="Sex", facet_values_or_threshold=[0], group_name="Age"
)

# %% [markdown]
# For our demo we provide the following information in BiasConfig API:
# * `label_values_or_threshold`: List of label value(s) or threshold to indicate positive outcome used for bias metrics. Here positive outcome is earning >$50,000.
# * `facet_name`: Sensitive columns of the dataset, "Sex" is the category
# * `facet_values_or_threshold`: values of the sensitive group, "Female" respondents are the sensitive group.
# * `group_name`: This example has selected the "Age" column which is used to form subgroups for the measurement of bias metric [Conditional Demographic Disparity (CDD)](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-data-bias-metric-cddl.html) or [Conditional Demographic Disparity in Predicted Labels (CDDPL)](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-post-training-bias-metric-cddpl.html).
#
# SageMaker Clarify can handle both categorical and continuous data for `facet: values_or_threshold` and for `label_values_or_threshold`. In this case we are using categorical data. The results will show if the model has a preference for records of one sex over the other.

# %% [markdown]
# #### Pre-training Bias
# Bias can be present in your data before any model training occurs. Inspecting your data for bias before training begins can help detect any data collection gaps, inform your feature engineering, and hep you understand what societal biases the data may reflect.
#
# Computing pre-training bias metrics does not require a trained model.
#
# #### Post-training Bias
# Computing post-training bias metrics does require a trained model.
#
# Unbiased training data (as determined by concepts of fairness measured by bias metric) may still result in biased model predictions after training. Whether this occurs depends on several factors including hyperparameter choices.
#
#
# You can run these options separately with `run_pre_training_bias()` and `run_post_training_bias()` or at the same time with `run_bias()` as shown below. We use following additional parameters for the api call:
# * `pre_training_methods`: Pre-training bias metrics to be computed. The detailed description of the metrics can be found on [Measure Pre-training Bias](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-measure-data-bias.html). This example sets methods to "all" to compute all the pre-training bias metrics.
# * `post_training_methods`: Post-training bias metrics to be computed. The detailed description of the metrics can be found on [Measure Post-training Bias](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-detect-post-training-bias.html). This example sets methods to "all" to compute all the post-training bias metrics.

# %%
# The job takes about 10 minutes to run
clarify_processor.run_bias(
    data_config=bias_data_config,
    bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predictions_config,
    pre_training_methods="all",
    post_training_methods="all",
)
# Out:
# INFO:sagemaker.clarify:Analysis Config: {'dataset_type': 'text/csv', 'headers': ['Target', 'Age', 'Workclass', 'fnlwgt', 'Education', 'Education-Num', 'Marital Status', 'Occupation', 'Relationship', 'Ethnic group', 'Sex', 'Capital Gain', 'Capital Loss', 'Hours per week', 'Country'], 'label': 'Target', 'label_values_or_threshold': [1], 'facet': [{'name_or_index': 'Sex', 'value_or_threshold': [0]}], 'group_variable': 'Age', 'methods': {'report': {'name': 'report', 'title': 'Analysis Report'}, 'pre_training_bias': {'methods': 'all'}, 'post_training_bias': {'methods': 'all'}}, 'predictor': {'model_name': 'DEMO-clarify-model-07-02-2023-03-52-02', 'instance_type': 'ml.m5.xlarge', 'initial_instance_count': 2, 'accept_type': 'text/csv', 'content_type': 'text/csv'}, 'probability_threshold': 0.8}
# INFO:sagemaker:Creating processing-job with name Clarify-Bias-2023-02-07-03-52-03-434
# ...............................2023-02-07 03:57:02,570 logging.conf not found when configuring logging, using default logging configuration.
# 2023-02-07 03:57:02,570 Starting SageMaker Clarify Processing job
# 2023-02-07 03:57:02,571 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2023-02-07 03:57:02,571 Analysis result path: /opt/ml/processing/output
# 2023-02-07 03:57:02,571 This host is algo-2.
# 2023-02-07 03:57:02,571 This host is NOT the leader.
# 2023-02-07 03:57:02,571 Number of hosts in the cluster is 2.
# 2023-02-07 03:57:02,575 Running Apache Spark™ cluster based analyzer to get explanations and metrics.
# 2023-02-07 03:57:02,575 Override smspark user config
# 2023-02-07 03:57:02,575 Submitting job to Spark cluster...
# 2023-02-07 03:57:02,576 spark_submit command: ['smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 03:57 smspark.cli  INFO     Parsing arguments. argv: ['/usr/local/bin/smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 03:57 smspark.cli  INFO     Raw spark options before processing: {'jars': '/opt/program/jars/', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 03:57 smspark.cli  INFO     App and app arguments: ['/usr/local/bin/analyzer_spark_application.py']
# 02-07 03:57 smspark.cli  INFO     Rendered spark options: {'jars': '/opt/program/jars/logback-classic-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar,/opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/log4j-over-slf4j-1.7.30.jar', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 03:57 smspark.cli  INFO     Initializing processing job.
# 02-07 03:57 smspark-submit INFO     {'current_host': 'algo-2', 'hosts': ['algo-1', 'algo-2']}
# 02-07 03:57 smspark-submit INFO     {'ProcessingJobArn': 'arn:aws:sagemaker:us-west-2:000000000000:processing-job/clarify-bias-2023-02-07-03-52-03-434', 'ProcessingJobName': 'Clarify-Bias-2023-02-07-03-52-03-434', 'AppSpecification': {'ImageUri': '306415355426.dkr.ecr.us-west-2.amazonaws.com/sagemaker-clarify-processing:1.0', 'ContainerEntrypoint': None, 'ContainerArguments': None}, 'ProcessingInputs': [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/data', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/train_data.csv', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/config', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-bias/analysis_config.json', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'LocalPath': '/opt/ml/processing/output', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-bias', 'S3UploadMode': 'EndOfJob'}, 'FeatureStoreOutput': None}], 'KmsKeyId': None}, 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 2, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 30, 'VolumeKmsKeyId': None}}, 'RoleArn': 'arn:aws:iam::000000000000:role/service-role/AmazonSageMaker-ExecutionRole-20220304T121686', 'StoppingCondition': {'MaxRuntimeInSeconds': 86400}}
# 02-07 03:57 smspark.cli  INFO     running spark submit command: spark-submit --master yarn --deploy-mode client --jars /opt/program/jars/logback-classic-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar,/opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/log4j-over-slf4j-1.7.30.jar /usr/local/bin/analyzer_spark_application.py
# 02-07 03:57 smspark-submit INFO     waiting for hosts
# 02-07 03:57 smspark-submit INFO     starting status server
# 02-07 03:57 smspark-submit INFO     Status server listening on algo-2:5555
# 02-07 03:57 smspark-submit INFO     bootstrapping cluster
# 02-07 03:57 smspark-submit INFO     transitioning from status INITIALIZING to BOOTSTRAPPING
# 02-07 03:57 smspark-submit INFO     copying aws jars
# 02-07 03:57 waitress     INFO     Serving on http://10.0.89.130:5555
# 02-07 03:57 smspark-submit INFO     Found hadoop jar hadoop-aws.jar
# 02-07 03:57 smspark-submit INFO     Optional jar jets3t-0.9.0.jar in /usr/lib/hadoop/lib does not exist
# 02-07 03:57 smspark-submit INFO     copying cluster config
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/hdfs-site.xml to /usr/lib/hadoop/etc/hadoop/hdfs-site.xml
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/core-site.xml to /usr/lib/hadoop/etc/hadoop/core-site.xml
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/yarn-site.xml to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/spark-defaults.conf to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/spark-env.sh to /usr/lib/spark/conf/spark-env.sh
# 02-07 03:57 root         INFO     Detected instance type: m5.xlarge with total memory: 16384M and total cores: 4
# 02-07 03:57 root         INFO     Writing default config to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 03:57 root         INFO     Configuration at /usr/lib/hadoop/etc/hadoop/yarn-site.xml is:
# <?xml version="1.0"?>
# <!-- Site specific YARN configuration properties -->
#  <configuration>
#      <property>
#          <name>yarn.resourcemanager.hostname</name>
#          <value>10.0.100.115</value>
#          <description>The hostname of the RM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.hostname</name>
#          <value>algo-2</value>
#          <description>The hostname of the NM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.webapp.address</name>
#          <value>algo-2:8042</value>
#      </property>
#      <property>
#          <name>yarn.nodemanager.vmem-pmem-ratio</name>
#          <value>5</value>
#          <description>Ratio between virtual memory to physical memory.</description>
#      </property>
#      <property>
#          <name>yarn.resourcemanager.am.max-attempts</name>
#          <value>1</value>
#          <description>The maximum number of application attempts.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.env-whitelist</name>
#          <value>JAVA_HOME,HADOOP_COMMON_HOME,HADOOP_HDFS_HOME,HADOOP_CONF_DIR,YARN_HOME,AWS_CONTAINER_CREDENTIALS_RELATIVE_URI,AWS_REGION</value>
#          <description>Environment variable whitelist</description>
#      </property>
#
#   <property>
#     <name>yarn.scheduler.minimum-allocation-mb</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.minimum-allocation-vcores</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-vcores</name>
#     <value>4</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.memory-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.cpu-vcores</name>
#     <value>4</value>
#   </property>
# </configuration>
# 02-07 03:57 root         INFO     Writing default config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 03:57 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.100.115
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# 02-07 03:57 root         INFO     Finished Yarn configuration files setup.
# 02-07 03:57 root         INFO     reading user configuration from /opt/ml/processing/input/conf/configuration.json
# 02-07 03:57 root         INFO     User configuration list or dict: {'Classification': 'spark-defaults', 'Properties': {'spark.driver.memory': '14169m'}} , type <class 'dict'>
# 02-07 03:57 root         INFO     Writing user config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 03:57 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.100.115
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# spark.driver.memory 14169m
# 02-07 03:57 smspark-submit INFO     waiting for cluster to be up
# 2023-02-07 03:57:00,735 logging.conf not found when configuring logging, using default logging configuration.
# 2023-02-07 03:57:00,736 Starting SageMaker Clarify Processing job
# 2023-02-07 03:57:00,736 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2023-02-07 03:57:00,736 Analysis result path: /opt/ml/processing/output
# 2023-02-07 03:57:00,737 This host is algo-1.
# 2023-02-07 03:57:00,737 This host is the leader.
# 2023-02-07 03:57:00,737 Number of hosts in the cluster is 2.
# 2023-02-07 03:57:00,961 Running Apache Spark™ cluster based analyzer to get explanations and metrics.
# 2023-02-07 03:57:00,969 Configuring spark to use default region us-west-2
# 2023-02-07 03:57:00,969 Override smspark user config
# 2023-02-07 03:57:00,969 Submitting job to Spark cluster...
# 2023-02-07 03:57:00,969 spark_submit command: ['smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 03:57 smspark.cli  INFO     Parsing arguments. argv: ['/usr/local/bin/smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 03:57 smspark.cli  INFO     Raw spark options before processing: {'jars': '/opt/program/jars/', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 03:57 smspark.cli  INFO     App and app arguments: ['/usr/local/bin/analyzer_spark_application.py']
# 02-07 03:57 smspark.cli  INFO     Rendered spark options: {'jars': '/opt/program/jars/log4j-over-slf4j-1.7.30.jar,/opt/program/jars/logback-classic-1.2.9.jar,/opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 03:57 smspark.cli  INFO     Initializing processing job.
# 02-07 03:57 smspark-submit INFO     {'current_host': 'algo-1', 'hosts': ['algo-1', 'algo-2']}
# 02-07 03:57 smspark-submit INFO     {'ProcessingJobArn': 'arn:aws:sagemaker:us-west-2:000000000000:processing-job/clarify-bias-2023-02-07-03-52-03-434', 'ProcessingJobName': 'Clarify-Bias-2023-02-07-03-52-03-434', 'AppSpecification': {'ImageUri': '306415355426.dkr.ecr.us-west-2.amazonaws.com/sagemaker-clarify-processing:1.0', 'ContainerEntrypoint': None, 'ContainerArguments': None}, 'ProcessingInputs': [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/data', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/train_data.csv', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/config', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-bias/analysis_config.json', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'LocalPath': '/opt/ml/processing/output', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-bias', 'S3UploadMode': 'EndOfJob'}, 'FeatureStoreOutput': None}], 'KmsKeyId': None}, 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 2, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 30, 'VolumeKmsKeyId': None}}, 'RoleArn': 'arn:aws:iam::000000000000:role/service-role/AmazonSageMaker-ExecutionRole-20220304T121686', 'StoppingCondition': {'MaxRuntimeInSeconds': 86400}}
# 02-07 03:57 smspark.cli  INFO     running spark submit command: spark-submit --master yarn --deploy-mode client --jars /opt/program/jars/log4j-over-slf4j-1.7.30.jar,/opt/program/jars/logback-classic-1.2.9.jar,/opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar /usr/local/bin/analyzer_spark_application.py
# 02-07 03:57 smspark-submit INFO     waiting for hosts
# 02-07 03:57 smspark-submit INFO     starting status server
# 02-07 03:57 smspark-submit INFO     Status server listening on algo-1:5555
# 02-07 03:57 smspark-submit INFO     bootstrapping cluster
# 02-07 03:57 smspark-submit INFO     transitioning from status INITIALIZING to BOOTSTRAPPING
# 02-07 03:57 smspark-submit INFO     copying aws jars
# 02-07 03:57 waitress     INFO     Serving on http://10.0.100.115:5555
# 02-07 03:57 smspark-submit INFO     Found hadoop jar hadoop-aws.jar
# 02-07 03:57 smspark-submit INFO     Optional jar jets3t-0.9.0.jar in /usr/lib/hadoop/lib does not exist
# 02-07 03:57 smspark-submit INFO     copying cluster config
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/hdfs-site.xml to /usr/lib/hadoop/etc/hadoop/hdfs-site.xml
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/core-site.xml to /usr/lib/hadoop/etc/hadoop/core-site.xml
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/yarn-site.xml to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/spark-defaults.conf to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 03:57 smspark-submit INFO     copying /opt/hadoop-config/spark-env.sh to /usr/lib/spark/conf/spark-env.sh
# 02-07 03:57 root         INFO     Detected instance type: m5.xlarge with total memory: 16384M and total cores: 4
# 02-07 03:57 root         INFO     Writing default config to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 03:57 root         INFO     Configuration at /usr/lib/hadoop/etc/hadoop/yarn-site.xml is:
# <?xml version="1.0"?>
# <!-- Site specific YARN configuration properties -->
#  <configuration>
#      <property>
#          <name>yarn.resourcemanager.hostname</name>
#          <value>10.0.100.115</value>
#          <description>The hostname of the RM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.hostname</name>
#          <value>algo-1</value>
#          <description>The hostname of the NM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.webapp.address</name>
#          <value>algo-1:8042</value>
#      </property>
#      <property>
#          <name>yarn.nodemanager.vmem-pmem-ratio</name>
#          <value>5</value>
#          <description>Ratio between virtual memory to physical memory.</description>
#      </property>
#      <property>
#          <name>yarn.resourcemanager.am.max-attempts</name>
#          <value>1</value>
#          <description>The maximum number of application attempts.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.env-whitelist</name>
#          <value>JAVA_HOME,HADOOP_COMMON_HOME,HADOOP_HDFS_HOME,HADOOP_CONF_DIR,YARN_HOME,AWS_CONTAINER_CREDENTIALS_RELATIVE_URI,AWS_REGION</value>
#          <description>Environment variable whitelist</description>
#      </property>
#
#   <property>
#     <name>yarn.scheduler.minimum-allocation-mb</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.minimum-allocation-vcores</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-vcores</name>
#     <value>4</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.memory-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.cpu-vcores</name>
#     <value>4</value>
#   </property>
# </configuration>
# 02-07 03:57 root         INFO     Writing default config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 03:57 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.100.115
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.executorEnv.AWS_DEFAULT_REGION=us-west-2
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# 02-07 03:57 root         INFO     Finished Yarn configuration files setup.
# 02-07 03:57 root         INFO     reading user configuration from /opt/ml/processing/input/conf/configuration.json
# 02-07 03:57 root         INFO     User configuration list or dict: {'Classification': 'spark-defaults', 'Properties': {'spark.driver.memory': '14169m'}} , type <class 'dict'>
# 02-07 03:57 root         INFO     Writing user config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 03:57 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.100.115
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.executorEnv.AWS_DEFAULT_REGION=us-west-2
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# spark.driver.memory 14169m
# WARNING: /usr/lib/hadoop/logs does not exist. Creating.
# Formatting using clusterid: CID-4bb99614-f416-4f52-b762-4d2ee8938dae
# 02-07 03:57 smspark-submit INFO     waiting for cluster to be up
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: /var/log/yarn/ does not exist. Creating.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: /usr/lib/hadoop/logs does not exist. Creating.
# WARNING: /var/log/yarn/ does not exist. Creating.
# 2023-02-07 03:57:05,171 WARN org.apache.hadoop.yarn.server.nodemanager.containermanager.monitor.ContainersMonitorImpl: NodeManager configured with 15.5 G physical memory allocated to containers, which is more than 80% of the total physical memory available (15.4 G). Thrashing might happen.
# 2023-02-07 03:57:05,595 WARN org.apache.hadoop.yarn.server.nodemanager.logaggregation.tracker.NMLogAggregationStatusTracker: Log Aggregation is disabled.So is the LogAggregationStatusTracker.
# 2023-02-07 03:57:06,215 WARN org.eclipse.jetty.webapp.WebInfConfiguration: Can't generate resourceBase as part of webapp tmp dir name: java.lang.NullPointerException
# Feb 07, 2023 3:57:06 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices as a root resource class
# Feb 07, 2023 3:57:06 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.webapp.GenericExceptionHandler as a provider class
# Feb 07, 2023 3:57:06 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver as a provider class
# Feb 07, 2023 3:57:06 AM com.sun.jersey.server.impl.application.WebApplicationImpl _initiate
# INFO: Initiating Jersey application, version 'Jersey: 1.19 02/11/2015 03:25 AM'
# Feb 07, 2023 3:57:06 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 3:57:06 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.webapp.GenericExceptionHandler to GuiceManagedComponentProvider with the scope "Singleton"
# 2023-02-07 03:57:06,362 WARN org.apache.hadoop.yarn.server.nodemanager.containermanager.monitor.ContainersMonitorImpl: NodeManager configured with 15.5 G physical memory allocated to containers, which is more than 80% of the total physical memory available (15.4 G). Thrashing might happen.
# 2023-02-07 03:57:06,866 WARN org.apache.hadoop.hdfs.server.namenode.FSNamesystem: Only one image storage directory (dfs.namenode.name.dir) configured. Beware of data loss due to lack of redundant storage directories!
# 2023-02-07 03:57:06,866 WARN org.apache.hadoop.hdfs.server.namenode.FSNamesystem: Only one namespace edits storage directory (dfs.namenode.edits.dir) configured. Beware of data loss due to lack of redundant storage directories!
# Feb 07, 2023 3:57:06 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices to GuiceManagedComponentProvider with the scope "Singleton"
# 02-07 03:57 smspark-submit INFO     cluster is up
# 02-07 03:57 smspark-submit INFO     transitioning from status BOOTSTRAPPING to WAITING
# 02-07 03:57 smspark-submit INFO     starting executor logs watcher
# 02-07 03:57 smspark-submit INFO     waiting for the primary to come up
# Starting executor logs watcher on log_dir: /var/log/yarn
# 02-07 03:57 smspark-submit INFO     waiting for the primary to go down
# 2023-02-07 03:57:07,318 WARN org.apache.hadoop.yarn.server.nodemanager.logaggregation.tracker.NMLogAggregationStatusTracker: Log Aggregation is disabled.So is the LogAggregationStatusTracker.
# 2023-02-07 03:57:08,141 WARN org.eclipse.jetty.webapp.WebInfConfiguration: Can't generate resourceBase as part of webapp tmp dir name: java.lang.NullPointerException
# Feb 07, 2023 3:57:08 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.resourcemanager.webapp.JAXBContextResolver as a provider class
# Feb 07, 2023 3:57:08 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.resourcemanager.webapp.RMWebServices as a root resource class
# Feb 07, 2023 3:57:08 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.webapp.GenericExceptionHandler as a provider class
# Feb 07, 2023 3:57:08 AM com.sun.jersey.server.impl.application.WebApplicationImpl _initiate
# INFO: Initiating Jersey application, version 'Jersey: 1.19 02/11/2015 03:25 AM'
# Feb 07, 2023 3:57:08 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.resourcemanager.webapp.JAXBContextResolver to GuiceManagedComponentProvider with the scope "Singleton"
# 2023-02-07 03:57:08,745 WARN org.eclipse.jetty.webapp.WebInfConfiguration: Can't generate resourceBase as part of webapp tmp dir name: java.lang.NullPointerException
# Feb 07, 2023 3:57:09 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices as a root resource class
# Feb 07, 2023 3:57:09 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.webapp.GenericExceptionHandler as a provider class
# Feb 07, 2023 3:57:09 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver as a provider class
# Feb 07, 2023 3:57:09 AM com.sun.jersey.server.impl.application.WebApplicationImpl _initiate
# INFO: Initiating Jersey application, version 'Jersey: 1.19 02/11/2015 03:25 AM'
# Feb 07, 2023 3:57:09 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 3:57:09 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.webapp.GenericExceptionHandler to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 3:57:09 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.webapp.GenericExceptionHandler to GuiceManagedComponentProvider with the scope "Singleton"
# 2023-02-07 03:57:10,043 INFO BlockStateChange: BLOCK* processReport 0xa70cf42956c3b916: Processing first storage report for DS-464e37fe-b53d-405a-a3e8-799b096b759d from datanode 484faab1-07f4-4f0c-83d5-e87708cd6d28
# 2023-02-07 03:57:10,048 INFO BlockStateChange: BLOCK* processReport 0xa70cf42956c3b916: from storage DS-464e37fe-b53d-405a-a3e8-799b096b759d node DatanodeRegistration(10.0.89.130:9866, datanodeUuid=484faab1-07f4-4f0c-83d5-e87708cd6d28, infoPort=9864, infoSecurePort=0, ipcPort=9867, storageInfo=lv=-57;cid=CID-4bb99614-f416-4f52-b762-4d2ee8938dae;nsid=1247163114;c=1675742223219), blocks: 0, hasStaleStorage: false, processing time: 6 msecs, invalidatedBlocks: 0
# Feb 07, 2023 3:57:10 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.resourcemanager.webapp.RMWebServices to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 3:57:10 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices to GuiceManagedComponentProvider with the scope "Singleton"
# 2023-02-07 03:57:10,582 INFO BlockStateChange: BLOCK* processReport 0xb1479039d14224a9: Processing first storage report for DS-43645d34-da66-4d1b-804e-7714c5439087 from datanode 3444ab39-cb27-4a83-8a89-dfb96a9637ce
# 2023-02-07 03:57:10,582 INFO BlockStateChange: BLOCK* processReport 0xb1479039d14224a9: from storage DS-43645d34-da66-4d1b-804e-7714c5439087 node DatanodeRegistration(10.0.100.115:9866, datanodeUuid=3444ab39-cb27-4a83-8a89-dfb96a9637ce, infoPort=9864, infoSecurePort=0, ipcPort=9867, storageInfo=lv=-57;cid=CID-4bb99614-f416-4f52-b762-4d2ee8938dae;nsid=1247163114;c=1675742223219), blocks: 0, hasStaleStorage: false, processing time: 0 msecs, invalidatedBlocks: 0
# 02-07 03:57 smspark-submit INFO     cluster is up
# 02-07 03:57 smspark-submit INFO     transitioning from status BOOTSTRAPPING to WAITING
# 02-07 03:57 smspark-submit INFO     starting executor logs watcher
# 02-07 03:57 smspark-submit INFO     start log event log publisher
# Starting executor logs watcher on log_dir: /var/log/yarn
# 02-07 03:57 sagemaker-spark-event-logs-publisher INFO     Spark event log not enabled.
# 02-07 03:57 smspark-submit INFO     Waiting for hosts to bootstrap: ['algo-1', 'algo-2']
# 02-07 03:57 smspark-submit INFO     Received host statuses: dict_items([('algo-1', StatusMessage(status='WAITING', timestamp='2023-02-07T03:57:11.295865')), ('algo-2', StatusMessage(status='WAITING', timestamp='2023-02-07T03:57:11.298916'))])
# 03:57:19.456 [Thread-6] WARN  org.apache.spark.deploy.yarn.Client - Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 2023-02-07 03:57:30,384 WARN org.apache.hadoop.yarn.server.resourcemanager.rmapp.RMAppImpl: The specific max attempts: 0 for application: 1 is invalid, because it is out of the range [1, 1]. Use the global max attempts instead.
# 2023-02-07 03:57:31,755 INFO SecurityLogger.org.apache.hadoop.ipc.Server: Auth successful for appattempt_1675742231005_0001_000001 (auth:SIMPLE)
# Handling create event for file: /var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/prelaunch.out
# Handling create event for file: /var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/prelaunch.err
# Handling create event for file: /var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/launch_container.sh
# Handling create event for file: /var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info
# Handling create event for file: /var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/stdout
# Handling create event for file: /var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/stderr
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] -rw-r--r-- 1 root root   74 Feb  7 03:57 container_tokens
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] -rwx------ 1 root root  723 Feb  7 03:57 default_container_executor.sh
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] -rwx------ 1 root root  668 Feb  7 03:57 default_container_executor_session.sh
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] -rwx------ 1 root root 5331 Feb  7 03:57 launch_container.sh
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   85 Feb  7 03:57 log4j-over-slf4j-1.7.30.jar -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/17/log4j-over-slf4j-1.7.30.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   83 Feb  7 03:57 logback-classic-1.2.9.jar -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/14/logback-classic-1.2.9.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   80 Feb  7 03:57 logback-core-1.2.9.jar -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/13/logback-core-1.2.9.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   77 Feb  7 03:57 py4j-0.10.9-src.zip -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/16/py4j-0.10.9-src.zip
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   69 Feb  7 03:57 pyspark.zip -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/10/pyspark.zip
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] drwx--x--- 2 root root 4096 Feb  7 03:57 tmp
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] find -L . -maxdepth 5 -ls:
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345807    4 drwx--x---   3 root     root         4096 Feb  7 03:57 .
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345817    4 -rw-r--r--   1 root     root           16 Feb  7 03:57 ./.default_container_executor.sh.crc
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345815    4 -rw-r--r--   1 root     root           16 Feb  7 03:57 ./.default_container_executor_session.sh.crc
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345799   24 -r-x------   1 root     root        23702 Feb  7 03:57 ./log4j-over-slf4j-1.7.30.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345790  232 -r-x------   1 root     root       233855 Feb  7 03:57 ./logback-classic-1.2.9.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345796   44 -r-x------   1 root     root        41587 Feb  7 03:57 ./py4j-0.10.9-src.zip
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345810    4 -rw-r--r--   1 root     root           74 Feb  7 03:57 ./container_tokens
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345464  872 -r-x------   1 root     root       889814 Feb  7 03:57 ./pyspark.zip
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345811    4 -rw-r--r--   1 root     root           12 Feb  7 03:57 ./.container_tokens.crc
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345813    4 -rw-r--r--   1 root     root           52 Feb  7 03:57 ./.launch_container.sh.crc
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345468   20 drwx------   2 root     root        20480 Feb  7 03:57 ./__spark_libs__
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345469 1712 -r-x------   1 root     root      1749371 Feb  7 03:57 ./__spark_libs__/netlib-native_ref-linux-x86_64-1.1-natives.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345470  276 -r-x------   1 root     root       281356 Feb  7 03:57 ./__spark_libs__/xbean-asm7-shaded-4.15.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345471  228 -r-x------   1 root     root       232248 Feb  7 03:57 ./__spark_libs__/jackson-core-asl-1.9.13.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345472  404 -r-x------   1 root     root       410874 Feb  7 03:57 ./__spark_libs__/kryo-shaded-4.0.2.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345473  544 -r-x------   1 root     root       553993 Feb  7 03:57 ./__spark_libs__/netlib-native_system-osx-x86_64-1.1-natives.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345474   20 -r-x------   1 root     root        19827 Feb  7 03:57 ./__spark_libs__/opencsv-2.3.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345475 10008 -r-x------   1 root     root     10247828 Feb  7 03:57 ./__spark_libs__/spark-catalyst_2.12-3.1.1-amzn-0.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345751   24 -r-x------   1 root     root        23702 Feb  7 03:57 ./__spark_libs__/log4j-over-slf4j-1.7.30.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345476   36 -r-x------   1 root     root        33205 Feb  7 03:57 ./__spark_libs__/jackson-jaxrs-base-2.10.5.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345477   16 -r-x------   1 root     root        15171 Feb  7 03:57 ./__spark_libs__/spark-tags_2.12-3.1.1-amzn-0.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345478   56 -r-x------   1 root     root        55236 Feb  7 03:57 ./__spark_libs__/geronimo-jcache_1.0_spec-1.0-alpha-1.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345479   28 -r-x------   1 root     root        25475 Feb  7 03:57 ./__spark_libs__/json-1.8.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345480 7948 -r-x------   1 root     root      8135275 Feb  7 03:57 ./__spark_libs__/spark-sql_2.12-3.1.1-amzn-0.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345481  576 -r-x------   1 root     root       588337 Feb  7 03:57 ./__spark_libs__/commons-collections-3.2.2.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345482  344 -r-x------   1 root     root       349059 Feb  7 03:57 ./__spark_libs__/json4s-scalap_2.12-3.7.0-M5.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345483 1152 -r-x------   1 root     root      1175798 Feb  7 03:57 ./__spark_libs__/JTransforms-3.1.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345484 1632 -r-x------   1 root     root      1669989 Feb  7 03:57 ./__spark_libs__/hadoop-mapreduce-client-core-3.2.1-amzn-3.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345485  116 -r-x------   1 root     root       117920 Feb  7 03:57 ./__spark_libs__/hive-jdbc-2.3.7-amzn-4.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345486   48 -r-x------   1 root     root        46781 Feb  7 03:57 ./__spark_libs__/jackson-dataformat-yaml-2.10.5.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345487  100 -r-x------   1 root     root       100431 Feb  7 03:57 ./__spark_libs__/pyrolite-4.30.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345488   64 -r-x------   1 root     root        62050 Feb  7 03:57 ./__spark_libs__/commons-logging-1.1.3.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345489    4 -r-x------   1 root     root         2500 Feb  7 03:57 ./__spark_libs__/shims-0.9.0.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345490   24 -r-x------   1 root     root        24239 Feb  7 03:57 ./__spark_libs__/commons-daemon-1.0.13.jar
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000001/directory.info] 1345491   48 -r-x------   1 root     root        48202 Feb  7 03:57 ./__spark_libs__/orc-mapreduce-1.5.12.jar
# ...
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:20.194+0000: [GC (Allocation Failure) [PSYoungGen: 4208131K->12068K(4207616K)] 4907797K->712054K(5184512K), 0.0216605 secs] [Times: user=0.03 sys=0.01, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:25.307+0000: [GC (Allocation Failure) [PSYoungGen: 4207396K->12132K(4213248K)] 4907382K->712446K(5190144K), 0.0184725 secs] [Times: user=0.03 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:30.407+0000: [GC (Allocation Failure) [PSYoungGen: 4206854K->12452K(4213248K)] 4907167K->713086K(5190144K), 0.0170252 secs] [Times: user=0.03 sys=0.00, real=0.01 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:35.677+0000: [GC (Allocation Failure) [PSYoungGen: 4207780K->12968K(4213760K)] 4908414K->713985K(5190656K), 0.0167600 secs] [Times: user=0.04 sys=0.00, real=0.01 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:40.787+0000: [GC (Allocation Failure) [PSYoungGen: 4209320K->13245K(4213760K)] 4910337K->714583K(5190656K), 0.0171988 secs] [Times: user=0.03 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:46.177+0000: [GC (Allocation Failure) [PSYoungGen: 4209597K->13352K(4214272K)] 4910935K->715042K(5191168K), 0.0209286 secs] [Times: user=0.03 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:04:53.285+0000: [GC (Allocation Failure) [PSYoungGen: 4209704K->17899K(4214272K)] 4911394K->726043K(5191168K), 0.0266240 secs] [Times: user=0.04 sys=0.01, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:05:03.001+0000: [GC (Allocation Failure) [PSYoungGen: 4214251K->17902K(4187648K)] 4922395K->748579K(5164544K), 0.0564037 secs] [Times: user=0.09 sys=0.01, real=0.06 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:05:10.579+0000: [GC (Allocation Failure) [PSYoungGen: 4187630K->19182K(4200960K)] 4918307K->750122K(5177856K), 0.0236509 secs] [Times: user=0.06 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:05:15.797+0000: [GC (Allocation Failure) [PSYoungGen: 4188681K->19034K(4199424K)] 4919621K->749982K(5176320K), 0.0236102 secs] [Times: user=0.05 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/stdout] 2023-02-07T04:05:22.933+0000: [GC (GCLocker Initiated GC) [PSYoungGen: 4189274K->27472K(4197888K)] 4920254K->758460K(5174784K), 0.0278555 secs] [Times: user=0.06 sys=0.00, real=0.03 secs]
# 2023-02-07 04:05:30,058 ['jupyter', 'nbconvert', '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 753540 bytes to /opt/ml/processing/output/report.html
# 2023-02-07 04:05:31,255 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2023-02-07 04:05:32,248 Collected analyses:
# {
#     "post_training_bias_metrics": {
#         "facets": {
#             "Sex": [
#                 {
#                     "metrics": [
#                         {
#                             "description": "Accuracy Difference (AD)",
#                             "name": "AD",
#                             "value": -0.1141572442143538
#                         },
#                         {
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "name": "CDDPL",
#                             "value": 0.19716203919079384
#                         },
#                         {
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "name": "DAR",
#                             "value": -0.007405223292617502
#                         },
#                         {
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "name": "DCA",
#                             "value": -0.22750276729134145
#                         },
#                         {
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "name": "DCR",
#                             "value": 0.13282504190308553
#                         },
#                         {
#                             "description": "Disparate Impact (DI)",
#                             "name": "DI",
#                             "value": 0.32939129409419415
#                         },
#                         {
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "name": "DPPL",
#                             "value": 0.0922004707530946
#                         },
#                         {
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "name": "DRR",
#                             "value": 0.13653296409568605
#                         },
#                         {
#                             "description": "Flip Test (FT)",
#                             "name": "FT",
#                             "value": -0.0009200572480065427
#                         },
#                         {
#                             "description": "Generalized Entropy (GE)",
#                             "name": "GE",
#                             "value": 0.08652737516063569
#                         },
#                         {
#                             "description": "Recall Difference (RD)",
#                             "name": "RD",
#                             "value": 0.03556460647616988
#                         },
#                         {
#                             "description": "Specificity Difference (SD)",
#                             "name": "SD",
#                             "value": 0.004853462451072765
#                         },
#                         {
#                             "description": "Treatment Equality (TE)",
#                             "name": "TE",
#                             "value": 24.11428571428572
#                         }
#                     ],
#                     "value_or_threshold": "0"
#                 }
#             ]
#         },
#         "label": "Target",
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "facets": {
#             "Sex": [
#                 {
#                     "metrics": [
#                         {
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "name": "CDDL",
#                             "value": 0.21491590864935592
#                         },
#                         {
#                             "description": "Class Imbalance (CI)",
#                             "name": "CI",
#                             "value": 0.3513692725946555
#                         },
#                         {
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "name": "DPL",
#                             "value": 0.20015891077100018
#                         },
#                         {
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "name": "JS",
#                             "value": 0.03075614465977302
#                         },
#                         {
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "name": "KL",
#                             "value": 0.14306865156306434
#                         },
#                         {
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "name": "KS",
#                             "value": 0.20015891077100018
#                         },
#                         {
#                             "description": "L-p Norm (LP)",
#                             "name": "LP",
#                             "value": 0.2830674462421746
#                         },
#                         {
#                             "description": "Total Variation Distance (TVD)",
#                             "name": "TVD",
#                             "value": 0.20015891077100015
#                         }
#                     ],
#                     "value_or_threshold": "0"
#                 }
#             ]
#         },
#         "label": "Target",
#         "label_value_or_threshold": "1"
#     },
#     "version": "1.0"
# }
# 2023-02-07 04:05:32,249 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# [/var/log/yarn/userlogs/application_1675742231005_0001/container_1675742231005_0001_01_000003/
# 02-07 04:05 urllib3.connectionpool WARNING  Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd4fc480640>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 2023-02-07 04:05:33,848 WARN org.apache.hadoop.hdfs.server.datanode.DataNode: IOException in offerService
# java.io.EOFException: End of File Exception between local host is: "algo-2/10.0.89.130"; destination host is: "algo-1":8020; : java.io.EOFException; For more details see:  http://wiki.apache.org/hadoop/EOFException
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# #011at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# #011at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# #011at org.apache.hadoop.net.NetUtils.wrapWithMessage(NetUtils.java:833)
# #011at org.apache.hadoop.net.NetUtils.wrapException(NetUtils.java:791)
# #011at org.apache.hadoop.ipc.Client.getRpcResponse(Client.java:1549)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1491)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1388)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:233)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:118)
# #011at com.sun.proxy.$Proxy16.sendHeartbeat(Unknown Source)
# #011at org.apache.hadoop.hdfs.protocolPB.DatanodeProtocolClientSideTranslatorPB.sendHeartbeat(DatanodeProtocolClientSideTranslatorPB.java:168)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.sendHeartBeat(BPServiceActor.java:517)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.offerService(BPServiceActor.java:648)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.run(BPServiceActor.java:849)
# #011at java.lang.Thread.run(Thread.java:750)
# Caused by: java.io.EOFException
# #011at java.io.DataInputStream.readInt(DataInputStream.java:392)
# #011at org.apache.hadoop.ipc.Client$IpcStreams.readResponse(Client.java:1850)
# #011at org.apache.hadoop.ipc.Client$Connection.receiveRpcResponse(Client.java:1183)
# #011at org.apache.hadoop.ipc.Client$Connection.run(Client.java:1079)
# 02-07 04:05 urllib3.connectionpool WARNING  Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd4fc480880>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:05 urllib3.connectionpool WARNING  Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd4fc4ac040>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:05 urllib3.connectionpool WARNING  Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd4fc4ac1f0>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 2023-02-07 04:05:46,852 WARN org.apache.hadoop.hdfs.server.datanode.DataNode: IOException in offerService
# java.net.ConnectException: Call From algo-2/10.0.89.130 to algo-1:8020 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# #011at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# #011at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# #011at org.apache.hadoop.net.NetUtils.wrapWithMessage(NetUtils.java:833)
# #011at org.apache.hadoop.net.NetUtils.wrapException(NetUtils.java:757)
# #011at org.apache.hadoop.ipc.Client.getRpcResponse(Client.java:1549)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1491)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1388)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:233)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:118)
# #011at com.sun.proxy.$Proxy16.sendHeartbeat(Unknown Source)
# #011at org.apache.hadoop.hdfs.protocolPB.DatanodeProtocolClientSideTranslatorPB.sendHeartbeat(DatanodeProtocolClientSideTranslatorPB.java:168)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.sendHeartBeat(BPServiceActor.java:517)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.offerService(BPServiceActor.java:648)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.run(BPServiceActor.java:849)
# #011at java.lang.Thread.run(Thread.java:750)
# Caused by: java.net.ConnectException: Connection refused
# #011at sun.nio.ch.SocketChannelImpl.checkConnect(Native Method)
# #011at sun.nio.ch.SocketChannelImpl.finishConnect(SocketChannelImpl.java:716)
# #011at org.apache.hadoop.net.SocketIOWithTimeout.connect(SocketIOWithTimeout.java:206)
# #011at org.apache.hadoop.net.NetUtils.connect(NetUtils.java:533)
# #011at org.apache.hadoop.ipc.Client$Connection.setupConnection(Client.java:700)
# #011at org.apache.hadoop.ipc.Client$Connection.setupIOstreams(Client.java:804)
# #011at org.apache.hadoop.ipc.Client$Connection.access$3800(Client.java:421)
# #011at org.apache.hadoop.ipc.Client.getConnection(Client.java:1606)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1435)
# #011... 9 more
# 02-07 04:05 urllib3.connectionpool WARNING  Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd4fc4ac400>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:05 smspark-submit INFO     primary is down, worker now exiting
# 2023-02-07 04:05:48,131 smspark submit job is executed
# 2023-02-07 04:05:48,131 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# [/var/log/yarn/userlogs/application_16757422

# %% [markdown]
# #### Viewing the Bias Report
# In Studio, you can view the results under the experiments tab.
#
# <img src="./recordings/bias_report.gif">
#
# Each bias metric has detailed explanations with examples that you can explore.
#
# <img src="./recordings/bias_detail.gif">
#
# You could also summarize the results in a handy table!
#
# <img src="./recordings/bias_report_chart.gif">

# %% [markdown]
# If you're not a Studio user yet, you can access the bias report in pdf, html and ipynb formats in the following S3 bucket:

# %%
bias_report_output_path
# Out:
# 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-bias'

# %% [markdown]
# ### Explaining Predictions
# There are expanding business needs and legislative regulations that require explanations of _why_ a model made the decision it did. SageMaker Clarify uses Kernel SHAP to explain the contribution that each input feature makes to the final decision.
#
# For run_explainability API call we need similar `DataConfig` and `ModelConfig` objects we defined above. [`SHAPConfig`](https://sagemaker.readthedocs.io/en/stable/api/training/processing.html#sagemaker.clarify.SHAPConfig) here is the config class for Kernel SHAP algorithm.
#
# For our demo we pass the following information in `SHAPConfig`:
# * `baseline`: Kernel SHAP algorithm requires a baseline (also known as background dataset). If not provided, a baseline is calculated automatically by SageMaker Clarify using K-means or K-prototypes in the input dataset. Baseline dataset type shall be the same as dataset_type, and baseline samples shall only include features. By definition, baseline should either be a S3 URI to the baseline dataset file, or an in-place list of samples. In this case we chose the latter, and put the mean of the train dataset to the list. For more details on baseline selection please [refer this documentation](https://docs.aws.amazon.com/en_us/sagemaker/latest/dg/clarify-feature-attribute-shap-baselines.html).
# * `num_samples`: Number of samples to be used in the Kernel SHAP algorithm. This number determines the size of the generated synthetic dataset to compute the SHAP values.
# * `agg_method`: Aggregation method for global SHAP values. For our example here we are using `mean_abs` i.e. mean of absolute SHAP values for all instances
# * `save_local_shap_values`: Indicates whether to save the local SHAP values in the output location. Default is True.

# %%
explainability_output_path = "s3://{}/{}/clarify-explainability".format(bucket, prefix)
explainability_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=explainability_output_path,
    label="Target",
    headers=training_data.columns.to_list(),
    dataset_type="text/csv",
)

baseline = [training_data.mean().iloc[1:].values.tolist()]
shap_config = clarify.SHAPConfig(
    baseline=baseline,
    num_samples=15,
    agg_method="mean_abs",
    save_local_shap_values=True,
)

# %%
# The job takes about 10 minutes to run
clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
)
# Out:
# INFO:sagemaker.clarify:Analysis Config: {'dataset_type': 'text/csv', 'headers': ['Target', 'Age', 'Workclass', 'fnlwgt', 'Education', 'Education-Num', 'Marital Status', 'Occupation', 'Relationship', 'Ethnic group', 'Sex', 'Capital Gain', 'Capital Loss', 'Hours per week', 'Country'], 'label': 'Target', 'predictor': {'model_name': 'DEMO-clarify-model-07-02-2023-03-52-02', 'instance_type': 'ml.m5.xlarge', 'initial_instance_count': 2, 'accept_type': 'text/csv', 'content_type': 'text/csv'}, 'methods': {'report': {'name': 'report', 'title': 'Analysis Report'}, 'shap': {'use_logit': False, 'save_local_shap_values': True, 'baseline': [[38.437901995888865, 2.1993236522777004, 189793.83393011073, 10.333764339234799, 10.12131158411246, 2.5801339433724553, 5.95985014256349, 1.4183409588223592, 3.6786022147072477, 0.6756846362973278, 1092.0078575691268, 88.37248856176646, 40.93123798156621, 36.382567469000726]], 'num_samples': 15, 'agg_method': 'mean_abs'}}}
# INFO:sagemaker:Creating processing-job with name Clarify-Explainability-2023-02-07-04-06-40-821
# ...............................2023-02-07 04:11:36,153 logging.conf not found when configuring logging, using default logging configuration.
# 2023-02-07 04:11:36,154 Starting SageMaker Clarify Processing job
# 2023-02-07 04:11:36,154 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2023-02-07 04:11:36,154 Analysis result path: /opt/ml/processing/output
# 2023-02-07 04:11:36,154 This host is algo-2.
# 2023-02-07 04:11:36,154 This host is NOT the leader.
# 2023-02-07 04:11:36,154 Number of hosts in the cluster is 2.
# 2023-02-07 04:11:36,158 Running Apache Spark™ cluster based analyzer to get explanations and metrics.
# 2023-02-07 04:11:36,158 Override smspark user config
# 2023-02-07 04:11:36,159 Submitting job to Spark cluster...
# 2023-02-07 04:11:36,159 spark_submit command: ['smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 04:11 smspark.cli  INFO     Parsing arguments. argv: ['/usr/local/bin/smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 04:11 smspark.cli  INFO     Raw spark options before processing: {'jars': '/opt/program/jars/', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 04:11 smspark.cli  INFO     App and app arguments: ['/usr/local/bin/analyzer_spark_application.py']
# 02-07 04:11 smspark.cli  INFO     Rendered spark options: {'jars': '/opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar,/opt/program/jars/log4j-over-slf4j-1.7.30.jar,/opt/program/jars/logback-classic-1.2.9.jar', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 04:11 smspark.cli  INFO     Initializing processing job.
# 02-07 04:11 smspark-submit INFO     {'current_host': 'algo-2', 'hosts': ['algo-1', 'algo-2']}
# 02-07 04:11 smspark-submit INFO     {'ProcessingJobArn': 'arn:aws:sagemaker:us-west-2:000000000000:processing-job/clarify-explainability-2023-02-07-04-06-40-821', 'ProcessingJobName': 'Clarify-Explainability-2023-02-07-04-06-40-821', 'AppSpecification': {'ImageUri': '306415355426.dkr.ecr.us-west-2.amazonaws.com/sagemaker-clarify-processing:1.0', 'ContainerEntrypoint': None, 'ContainerArguments': None}, 'ProcessingInputs': [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/data', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/train_data.csv', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/config', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-explainability/analysis_config.json', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'LocalPath': '/opt/ml/processing/output', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-explainability', 'S3UploadMode': 'EndOfJob'}, 'FeatureStoreOutput': None}], 'KmsKeyId': None}, 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 2, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 30, 'VolumeKmsKeyId': None}}, 'RoleArn': 'arn:aws:iam::000000000000:role/service-role/AmazonSageMaker-ExecutionRole-20220304T121686', 'StoppingCondition': {'MaxRuntimeInSeconds': 86400}}
# 02-07 04:11 smspark.cli  INFO     running spark submit command: spark-submit --master yarn --deploy-mode client --jars /opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar,/opt/program/jars/log4j-over-slf4j-1.7.30.jar,/opt/program/jars/logback-classic-1.2.9.jar /usr/local/bin/analyzer_spark_application.py
# 02-07 04:11 smspark-submit INFO     waiting for hosts
# 02-07 04:11 smspark-submit INFO     starting status server
# 02-07 04:11 smspark-submit INFO     Status server listening on algo-2:5555
# 02-07 04:11 smspark-submit INFO     bootstrapping cluster
# 02-07 04:11 smspark-submit INFO     transitioning from status INITIALIZING to BOOTSTRAPPING
# 02-07 04:11 smspark-submit INFO     copying aws jars
# 02-07 04:11 waitress     INFO     Serving on http://10.0.122.113:5555
# 02-07 04:11 smspark-submit INFO     Found hadoop jar hadoop-aws-3.2.1-amzn-3.jar
# 02-07 04:11 smspark-submit INFO     Optional jar jets3t-0.9.0.jar in /usr/lib/hadoop/lib does not exist
# 02-07 04:11 smspark-submit INFO     copying cluster config
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/hdfs-site.xml to /usr/lib/hadoop/etc/hadoop/hdfs-site.xml
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/core-site.xml to /usr/lib/hadoop/etc/hadoop/core-site.xml
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/yarn-site.xml to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/spark-defaults.conf to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/spark-env.sh to /usr/lib/spark/conf/spark-env.sh
# 02-07 04:11 root         INFO     Detected instance type: m5.xlarge with total memory: 16384M and total cores: 4
# 02-07 04:11 root         INFO     Writing default config to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 04:11 root         INFO     Configuration at /usr/lib/hadoop/etc/hadoop/yarn-site.xml is:
# <?xml version="1.0"?>
# <!-- Site specific YARN configuration properties -->
#  <configuration>
#      <property>
#          <name>yarn.resourcemanager.hostname</name>
#          <value>10.0.104.48</value>
#          <description>The hostname of the RM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.hostname</name>
#          <value>algo-2</value>
#          <description>The hostname of the NM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.webapp.address</name>
#          <value>algo-2:8042</value>
#      </property>
#      <property>
#          <name>yarn.nodemanager.vmem-pmem-ratio</name>
#          <value>5</value>
#          <description>Ratio between virtual memory to physical memory.</description>
#      </property>
#      <property>
#          <name>yarn.resourcemanager.am.max-attempts</name>
#          <value>1</value>
#          <description>The maximum number of application attempts.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.env-whitelist</name>
#          <value>JAVA_HOME,HADOOP_COMMON_HOME,HADOOP_HDFS_HOME,HADOOP_CONF_DIR,YARN_HOME,AWS_CONTAINER_CREDENTIALS_RELATIVE_URI,AWS_REGION</value>
#          <description>Environment variable whitelist</description>
#      </property>
#
#   <property>
#     <name>yarn.scheduler.minimum-allocation-mb</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.minimum-allocation-vcores</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-vcores</name>
#     <value>4</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.memory-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.cpu-vcores</name>
#     <value>4</value>
#   </property>
# </configuration>
# 02-07 04:11 root         INFO     Writing default config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 04:11 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.104.48
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# 02-07 04:11 root         INFO     Finished Yarn configuration files setup.
# 02-07 04:11 root         INFO     reading user configuration from /opt/ml/processing/input/conf/configuration.json
# 02-07 04:11 root         INFO     User configuration list or dict: {'Classification': 'spark-defaults', 'Properties': {'spark.driver.memory': '14169m'}} , type <class 'dict'>
# 02-07 04:11 root         INFO     Writing user config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 04:11 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.104.48
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# spark.driver.memory 14169m
# 02-07 04:11 smspark-submit INFO     waiting for cluster to be up
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: /var/log/yarn/ does not exist. Creating.
# WARNING: /usr/lib/hadoop/logs does not exist. Creating.
# 2023-02-07 04:11:38,805 WARN org.apache.hadoop.yarn.server.nodemanager.containermanager.monitor.ContainersMonitorImpl: NodeManager configured with 15.5 G physical memory allocated to containers, which is more than 80% of the total physical memory available (15.4 G). Thrashing might happen.
# 2023-02-07 04:11:39,192 WARN org.apache.hadoop.yarn.server.nodemanager.logaggregation.tracker.NMLogAggregationStatusTracker: Log Aggregation is disabled.So is the LogAggregationStatusTracker.
# 2023-02-07 04:11:39,800 WARN org.eclipse.jetty.webapp.WebInfConfiguration: Can't generate resourceBase as part of webapp tmp dir name: java.lang.NullPointerException
# Feb 07, 2023 4:11:39 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices as a root resource class
# Feb 07, 2023 4:11:39 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.webapp.GenericExceptionHandler as a provider class
# Feb 07, 2023 4:11:39 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver as a provider class
# Feb 07, 2023 4:11:39 AM com.sun.jersey.server.impl.application.WebApplicationImpl _initiate
# INFO: Initiating Jersey application, version 'Jersey: 1.19 02/11/2015 03:25 AM'
# Feb 07, 2023 4:11:40 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 4:11:40 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.webapp.GenericExceptionHandler to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 4:11:40 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices to GuiceManagedComponentProvider with the scope "Singleton"
# 02-07 04:11 smspark-submit INFO     cluster is up
# 02-07 04:11 smspark-submit INFO     transitioning from status BOOTSTRAPPING to WAITING
# 02-07 04:11 smspark-submit INFO     starting executor logs watcher
# Starting executor logs watcher on log_dir: /var/log/yarn
# 02-07 04:11 smspark-submit INFO     waiting for the primary to come up
# 02-07 04:11 urllib3.connectionpool WARNING  Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa990790310>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:11 urllib3.connectionpool WARNING  Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa9907905e0>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:11 smspark-submit INFO     waiting for the primary to go down
# 2023-02-07 04:11:40,647 logging.conf not found when configuring logging, using default logging configuration.
# 2023-02-07 04:11:40,647 Starting SageMaker Clarify Processing job
# 2023-02-07 04:11:40,648 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2023-02-07 04:11:40,648 Analysis result path: /opt/ml/processing/output
# 2023-02-07 04:11:40,648 This host is algo-1.
# 2023-02-07 04:11:40,648 This host is the leader.
# 2023-02-07 04:11:40,648 Number of hosts in the cluster is 2.
# 2023-02-07 04:11:40,888 Running Apache Spark™ cluster based analyzer to get explanations and metrics.
# 2023-02-07 04:11:40,896 Configuring spark to use default region us-west-2
# 2023-02-07 04:11:40,896 Override smspark user config
# 2023-02-07 04:11:40,896 Submitting job to Spark cluster...
# 2023-02-07 04:11:40,897 spark_submit command: ['smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 04:11 smspark.cli  INFO     Parsing arguments. argv: ['/usr/local/bin/smspark-submit', '--jars', '/opt/program/jars/', '/usr/local/bin/analyzer_spark_application.py']
# 02-07 04:11 smspark.cli  INFO     Raw spark options before processing: {'jars': '/opt/program/jars/', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 04:11 smspark.cli  INFO     App and app arguments: ['/usr/local/bin/analyzer_spark_application.py']
# 02-07 04:11 smspark.cli  INFO     Rendered spark options: {'jars': '/opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar,/opt/program/jars/logback-classic-1.2.9.jar,/opt/program/jars/log4j-over-slf4j-1.7.30.jar', 'class_': None, 'py_files': None, 'files': None, 'verbose': False}
# 02-07 04:11 smspark.cli  INFO     Initializing processing job.
# 02-07 04:11 smspark-submit INFO     {'current_host': 'algo-1', 'hosts': ['algo-1', 'algo-2']}
# 02-07 04:11 smspark-submit INFO     {'ProcessingJobArn': 'arn:aws:sagemaker:us-west-2:000000000000:processing-job/clarify-explainability-2023-02-07-04-06-40-821', 'ProcessingJobName': 'Clarify-Explainability-2023-02-07-04-06-40-821', 'AppSpecification': {'ImageUri': '306415355426.dkr.ecr.us-west-2.amazonaws.com/sagemaker-clarify-processing:1.0', 'ContainerEntrypoint': None, 'ContainerArguments': None}, 'ProcessingInputs': [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/data', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/train_data.csv', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'LocalPath': '/opt/ml/processing/input/config', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-explainability/analysis_config.json', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}, 'DatasetDefinition': None}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'LocalPath': '/opt/ml/processing/output', 'S3Uri': 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-explainability', 'S3UploadMode': 'EndOfJob'}, 'FeatureStoreOutput': None}], 'KmsKeyId': None}, 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 2, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 30, 'VolumeKmsKeyId': None}}, 'RoleArn': 'arn:aws:iam::000000000000:role/service-role/AmazonSageMaker-ExecutionRole-20220304T121686', 'StoppingCondition': {'MaxRuntimeInSeconds': 86400}}
# 02-07 04:11 smspark.cli  INFO     running spark submit command: spark-submit --master yarn --deploy-mode client --jars /opt/program/jars/logback-core-1.2.9.jar,/opt/program/jars/SMClarify-assembly-0.1.jar,/opt/program/jars/logback-classic-1.2.9.jar,/opt/program/jars/log4j-over-slf4j-1.7.30.jar /usr/local/bin/analyzer_spark_application.py
# 02-07 04:11 smspark-submit INFO     waiting for hosts
# 02-07 04:11 smspark-submit INFO     starting status server
# 02-07 04:11 smspark-submit INFO     Status server listening on algo-1:5555
# 02-07 04:11 smspark-submit INFO     bootstrapping cluster
# 02-07 04:11 smspark-submit INFO     transitioning from status INITIALIZING to BOOTSTRAPPING
# 02-07 04:11 smspark-submit INFO     copying aws jars
# 02-07 04:11 waitress     INFO     Serving on http://10.0.104.48:5555
# 02-07 04:11 smspark-submit INFO     Found hadoop jar hadoop-aws-3.2.1-amzn-3.jar
# 02-07 04:11 smspark-submit INFO     Optional jar jets3t-0.9.0.jar in /usr/lib/hadoop/lib does not exist
# 02-07 04:11 smspark-submit INFO     copying cluster config
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/hdfs-site.xml to /usr/lib/hadoop/etc/hadoop/hdfs-site.xml
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/core-site.xml to /usr/lib/hadoop/etc/hadoop/core-site.xml
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/yarn-site.xml to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/spark-defaults.conf to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 04:11 smspark-submit INFO     copying /opt/hadoop-config/spark-env.sh to /usr/lib/spark/conf/spark-env.sh
# 02-07 04:11 root         INFO     Detected instance type: m5.xlarge with total memory: 16384M and total cores: 4
# 02-07 04:11 root         INFO     Writing default config to /usr/lib/hadoop/etc/hadoop/yarn-site.xml
# 02-07 04:11 root         INFO     Configuration at /usr/lib/hadoop/etc/hadoop/yarn-site.xml is:
# <?xml version="1.0"?>
# <!-- Site specific YARN configuration properties -->
#  <configuration>
#      <property>
#          <name>yarn.resourcemanager.hostname</name>
#          <value>10.0.104.48</value>
#          <description>The hostname of the RM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.hostname</name>
#          <value>algo-1</value>
#          <description>The hostname of the NM.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.webapp.address</name>
#          <value>algo-1:8042</value>
#      </property>
#      <property>
#          <name>yarn.nodemanager.vmem-pmem-ratio</name>
#          <value>5</value>
#          <description>Ratio between virtual memory to physical memory.</description>
#      </property>
#      <property>
#          <name>yarn.resourcemanager.am.max-attempts</name>
#          <value>1</value>
#          <description>The maximum number of application attempts.</description>
#      </property>
#      <property>
#          <name>yarn.nodemanager.env-whitelist</name>
#          <value>JAVA_HOME,HADOOP_COMMON_HOME,HADOOP_HDFS_HOME,HADOOP_CONF_DIR,YARN_HOME,AWS_CONTAINER_CREDENTIALS_RELATIVE_URI,AWS_REGION</value>
#          <description>Environment variable whitelist</description>
#      </property>
#
#   <property>
#     <name>yarn.scheduler.minimum-allocation-mb</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.minimum-allocation-vcores</name>
#     <value>1</value>
#   </property>
#   <property>
#     <name>yarn.scheduler.maximum-allocation-vcores</name>
#     <value>4</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.memory-mb</name>
#     <value>15892</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.resource.cpu-vcores</name>
#     <value>4</value>
#   </property>
# </configuration>
# 02-07 04:11 root         INFO     Writing default config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 04:11 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.104.48
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.executorEnv.AWS_DEFAULT_REGION=us-west-2
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# 02-07 04:11 root         INFO     Finished Yarn configuration files setup.
# 02-07 04:11 root         INFO     reading user configuration from /opt/ml/processing/input/conf/configuration.json
# 02-07 04:11 root         INFO     User configuration list or dict: {'Classification': 'spark-defaults', 'Properties': {'spark.driver.memory': '14169m'}} , type <class 'dict'>
# 02-07 04:11 root         INFO     Writing user config to /usr/lib/spark/conf/spark-defaults.conf
# 02-07 04:11 root         INFO     Configuration at /usr/lib/spark/conf/spark-defaults.conf is:
# spark.driver.extraClassPath      /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.driver.extraLibraryPath    /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.executor.extraClassPath    /usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/emrfs/conf:/usr/share/aws/emr/emrfs/lib/*:/usr/share/aws/emr/emrfs/auxlib/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar
# spark.executor.extraLibraryPath  /usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native
# spark.driver.host=10.0.104.48
# spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version=2
# # Fix for "Uncaught exception: org.apache.spark.rpc.RpcTimeoutException: Cannot
# # receive any reply from 10.0.109.30:35219 in 120 seconds.""
# spark.rpc.askTimeout=300s
# spark.network.timeout=600
# spark.sql.caseSensitive=true
# spark.executorEnv.AWS_DEFAULT_REGION=us-west-2
# spark.driver.memory 2048m
# spark.driver.memoryOverhead 204m
# spark.driver.defaultJavaOptions -XX:OnOutOfMemoryError='kill -9 %p' -XX:+UseConcMarkSweepGC -XX:CMSInitiatingOccupancyFraction=70 -XX:MaxHeapFreeRatio=70 -XX:+CMSClassUnloadingEnabled
# spark.executor.memory 12399m
# spark.executor.memoryOverhead 1239m
# spark.executor.cores 4
# spark.executor.defaultJavaOptions -verbose:gc -XX:OnOutOfMemoryError='kill -9 %p' -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:+UseParallelGC -XX:InitiatingHeapOccupancyPercent=70 -XX:ConcGCThreads=1 -XX:ParallelGCThreads=3
# spark.executor.instances 2
# spark.default.parallelism 16
# spark.yarn.appMasterEnv.AWS_REGION us-west-2
# spark.executorEnv.AWS_REGION us-west-2
# spark.driver.memory 14169m
# WARNING: /usr/lib/hadoop/logs does not exist. Creating.
# Formatting using clusterid: CID-e58840a0-efa1-4d47-9c8c-6758b9fd539b
# 02-07 04:11 smspark-submit INFO     waiting for cluster to be up
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: /var/log/yarn/ does not exist. Creating.
# 2023-02-07 04:11:46,564 WARN org.apache.hadoop.yarn.server.nodemanager.containermanager.monitor.ContainersMonitorImpl: NodeManager configured with 15.5 G physical memory allocated to containers, which is more than 80% of the total physical memory available (15.4 G). Thrashing might happen.
# 2023-02-07 04:11:47,460 WARN org.apache.hadoop.hdfs.server.namenode.FSNamesystem: Only one image storage directory (dfs.namenode.name.dir) configured. Beware of data loss due to lack of redundant storage directories!
# 2023-02-07 04:11:47,461 WARN org.apache.hadoop.hdfs.server.namenode.FSNamesystem: Only one namespace edits storage directory (dfs.namenode.edits.dir) configured. Beware of data loss due to lack of redundant storage directories!
# 2023-02-07 04:11:47,651 WARN org.apache.hadoop.yarn.server.nodemanager.logaggregation.tracker.NMLogAggregationStatusTracker: Log Aggregation is disabled.So is the LogAggregationStatusTracker.
# 2023-02-07 04:11:48,495 WARN org.eclipse.jetty.webapp.WebInfConfiguration: Can't generate resourceBase as part of webapp tmp dir name: java.lang.NullPointerException
# 2023-02-07 04:11:48,886 WARN org.eclipse.jetty.webapp.WebInfConfiguration: Can't generate resourceBase as part of webapp tmp dir name: java.lang.NullPointerException
# Feb 07, 2023 4:11:48 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.resourcemanager.webapp.JAXBContextResolver as a provider class
# Feb 07, 2023 4:11:48 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.resourcemanager.webapp.RMWebServices as a root resource class
# Feb 07, 2023 4:11:48 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.webapp.GenericExceptionHandler as a provider class
# Feb 07, 2023 4:11:48 AM com.sun.jersey.server.impl.application.WebApplicationImpl _initiate
# INFO: Initiating Jersey application, version 'Jersey: 1.19 02/11/2015 03:25 AM'
# Feb 07, 2023 4:11:49 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.resourcemanager.webapp.JAXBContextResolver to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 4:11:49 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices as a root resource class
# Feb 07, 2023 4:11:49 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.webapp.GenericExceptionHandler as a provider class
# Feb 07, 2023 4:11:49 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory register
# INFO: Registering org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver as a provider class
# Feb 07, 2023 4:11:49 AM com.sun.jersey.server.impl.application.WebApplicationImpl _initiate
# INFO: Initiating Jersey application, version 'Jersey: 1.19 02/11/2015 03:25 AM'
# Feb 07, 2023 4:11:49 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.JAXBContextResolver to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 4:11:50 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.webapp.GenericExceptionHandler to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 4:11:50 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.webapp.GenericExceptionHandler to GuiceManagedComponentProvider with the scope "Singleton"
# 2023-02-07 04:11:50,876 INFO BlockStateChange: BLOCK* processReport 0x3522440c3f06a869: Processing first storage report for DS-7b4e83e9-8ebb-4979-bea5-ca534c896b85 from datanode d8e4a92e-f0b8-426b-aee8-aca60db8cd40
# 2023-02-07 04:11:50,877 INFO BlockStateChange: BLOCK* processReport 0x3522440c3f06a869: from storage DS-7b4e83e9-8ebb-4979-bea5-ca534c896b85 node DatanodeRegistration(10.0.122.113:9866, datanodeUuid=d8e4a92e-f0b8-426b-aee8-aca60db8cd40, infoPort=9864, infoSecurePort=0, ipcPort=9867, storageInfo=lv=-57;cid=CID-e58840a0-efa1-4d47-9c8c-6758b9fd539b;nsid=1254288633;c=1675743103159), blocks: 0, hasStaleStorage: false, processing time: 3 msecs, invalidatedBlocks: 0
# Feb 07, 2023 4:11:50 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.nodemanager.webapp.NMWebServices to GuiceManagedComponentProvider with the scope "Singleton"
# Feb 07, 2023 4:11:51 AM com.sun.jersey.guice.spi.container.GuiceComponentProviderFactory getComponentProvider
# INFO: Binding org.apache.hadoop.yarn.server.resourcemanager.webapp.RMWebServices to GuiceManagedComponentProvider with the scope "Singleton"
# 2023-02-07 04:11:51,567 INFO BlockStateChange: BLOCK* processReport 0x7d4d565c682cb2e9: Processing first storage report for DS-d50edf3b-e4c8-482c-891a-26f3db21f634 from datanode 7cc65106-759e-4c85-b5e8-311c6873b9af
# 2023-02-07 04:11:51,568 INFO BlockStateChange: BLOCK* processReport 0x7d4d565c682cb2e9: from storage DS-d50edf3b-e4c8-482c-891a-26f3db21f634 node DatanodeRegistration(10.0.104.48:9866, datanodeUuid=7cc65106-759e-4c85-b5e8-311c6873b9af, infoPort=9864, infoSecurePort=0, ipcPort=9867, storageInfo=lv=-57;cid=CID-e58840a0-efa1-4d47-9c8c-6758b9fd539b;nsid=1254288633;c=1675743103159), blocks: 0, hasStaleStorage: false, processing time: 0 msecs, invalidatedBlocks: 0
# 02-07 04:11 smspark-submit INFO     cluster is up
# 02-07 04:11 smspark-submit INFO     transitioning from status BOOTSTRAPPING to WAITING
# 02-07 04:11 smspark-submit INFO     starting executor logs watcher
# 02-07 04:11 smspark-submit INFO     start log event log publisher
# Starting executor logs watcher on log_dir: /var/log/yarn
# 02-07 04:11 sagemaker-spark-event-logs-publisher INFO     Spark event log not enabled.
# 02-07 04:11 smspark-submit INFO     Waiting for hosts to bootstrap: ['algo-1', 'algo-2']
# 02-07 04:11 smspark-submit INFO     Received host statuses: dict_items([('algo-1', StatusMessage(status='WAITING', timestamp='2023-02-07T04:11:52.105721')), ('algo-2', StatusMessage(status='WAITING', timestamp='2023-02-07T04:11:52.109237'))])
# 04:12:00.573 [Thread-6] WARN  org.apache.spark.deploy.yarn.Client - Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 2023-02-07 04:12:11,440 WARN org.apache.hadoop.yarn.server.resourcemanager.rmapp.RMAppImpl: The specific max attempts: 0 for application: 1 is invalid, because it is out of the range [1, 1]. Use the global max attempts instead.
# 2023-02-07 04:12:12,436 INFO SecurityLogger.org.apache.hadoop.ipc.Server: Auth successful for appattempt_1675743111931_0001_000001 (auth:SIMPLE)
# Handling create event for file: /var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/prelaunch.out
# Handling create event for file: /var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/prelaunch.err
# Handling create event for file: /var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/launch_container.sh
# Handling create event for file: /var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info
# Handling create event for file: /var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/stdout
# Handling create event for file: /var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/stderr
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] -rwx------ 1 root root  723 Feb  7 04:12 default_container_executor.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] -rwx------ 1 root root  668 Feb  7 04:12 default_container_executor_session.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] -rwx------ 1 root root 5329 Feb  7 04:12 launch_container.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   85 Feb  7 04:12 log4j-over-slf4j-1.7.30.jar -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/17/log4j-over-slf4j-1.7.30.jar
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   83 Feb  7 04:12 logback-classic-1.2.9.jar -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/14/logback-classic-1.2.9.jar
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   80 Feb  7 04:12 logback-core-1.2.9.jar -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/13/logback-core-1.2.9.jar
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   77 Feb  7 04:12 py4j-0.10.9-src.zip -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/16/py4j-0.10.9-src.zip
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] lrwxrwxrwx 1 root root   69 Feb  7 04:12 pyspark.zip -> /tmp/hadoop-root/nm-local-dir/usercache/root/filecache/10/pyspark.zip
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] drwx--x--- 2 root root 4096 Feb  7 04:12 tmp
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] find -L . -maxdepth 5 -ls:
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448436    4 drwx--x---   3 root     root         4096 Feb  7 04:12 .
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448416  444 -r-x------   1 root     root       454201 Feb  7 04:12 ./logback-core-1.2.9.jar
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448445    4 -rwx------   1 root     root          723 Feb  7 04:12 ./default_container_executor.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448443    4 -rwx------   1 root     root          668 Feb  7 04:12 ./default_container_executor_session.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448422  872 -r-x------   1 root     root       892581 Feb  7 04:12 ./SMClarify-assembly-0.1.jar
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448438    4 drwx--x---   2 root     root         4096 Feb  7 04:12 ./tmp
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448442    4 -rw-r--r--   1 root     root           52 Feb  7 04:12 ./.launch_container.sh.crc
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448386    4 drwx------   3 root     root         4096 Feb  7 04:12 ./__spark_conf__
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448413    4 -r-x------   1 root     root         3341 Feb  7 04:12 ./__spark_conf__/__spark_conf__.properties
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448387   16 -r-x------   1 root     root        15000 Feb  7 04:12 ./__spark_conf__/log4j.properties
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448388    4 drwx------   2 root     root         4096 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448394   12 -r-x------   1 root     root         8260 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/capacity-scheduler.xml.default
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448407   12 -r-x------   1 root     root        11392 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/hadoop-policy.xml
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448408    4 -r-x------   1 root     root         3593 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/container-log4j.properties
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448397    4 -r-x------   1 root     root         1061 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/logback.xml
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448398   12 -r-x------   1 root     root         8260 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/capacity-scheduler.xml
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448391   16 -r-x------   1 root     root        15000 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/log4j.properties
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448406   16 -r-x------   1 root     root        14890 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/log4j.properties.default
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448405    4 -r-x------   1 root     root         2316 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/ssl-client.xml.example
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448396    4 -r-x------   1 root     root           10 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/workers
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448395    4 -r-x------   1 root     root          985 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/core-site.xml
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448392    4 -r-x------   1 root     root         3321 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/hadoop-metrics2.properties
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448409    4 -r-x------   1 root     root         2697 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/ssl-server.xml.example
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448411    4 -r-x------   1 root     root         1764 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/mapred-env.sh.default
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448390   16 -r-x------   1 root     root        16379 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/hadoop-env.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448389    4 -r-x------   1 root     root          758 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/mapred-site.xml
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448402    4 -r-x------   1 root     root          867 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/hdfs-site.xml
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448404    4 -r-x------   1 root     root         1764 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/mapred-env.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448403    4 -r-x------   1 root     root         1940 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/container-executor.cfg
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448401    8 -r-x------   1 root     root         6090 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/yarn-env.sh
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000001/directory.info] 1448393    4 -r-x------   1 root     root         1911 Feb  7 04:12 ./__spark_conf__/__hadoop_conf__/yarn-site.xml
# ...
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:12:24.108+0000: [GC (Metadata GC Threshold) [PSYoungGen: 36640K->4648K(130560K)] 42594K->10602K(226304K), 0.0103445 secs] [Times: user=0.02 sys=0.01, real=0.01 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:12:24.119+0000: [Full GC (Metadata GC Threshold) [PSYoungGen: 4648K->0K(130560K)] [ParOldGen: 5953K->9204K(144384K)] 10602K->9204K(274944K), [Metaspace: 33962K->33962K(1079296K)], 0.0377162 secs] [Times: user=0.06 sys=0.00, real=0.04 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:12:26.922+0000: [GC (Allocation Failure) [PSYoungGen: 120320K->10238K(130560K)] 129532K->28344K(274944K), 0.0217679 secs] [Times: user=0.04 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:12:27.140+0000: [GC (Metadata GC Threshold) [PSYoungGen: 34538K->10232K(192000K)] 52643K->28337K(336384K), 0.0148020 secs] [Times: user=0.04 sys=0.00, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:12:27.155+0000: [Full GC (Metadata GC Threshold) [PSYoungGen: 10232K->0K(192000K)] [ParOldGen: 18105K->17508K(193024K)] 28337K->17508K(385024K), [Metaspace: 56594K->56594K(1101824K)], 0.0953357 secs] [Times: user=0.22 sys=0.00, real=0.10 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:12:33.314+0000: [GC (Allocation Failure) [PSYoungGen: 175616K->12761K(191488K)] 193124K->30277K(384512K), 0.0181103 secs] [Times: user=0.04 sys=0.01, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:15:39.505+0000: [GC (Allocation Failure) [PSYoungGen: 188377K->12902K(232960K)] 205893K->30427K(425984K), 0.0191045 secs] [Times: user=0.04 sys=0.01, real=0.02 secs]
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000002/stdout] 2023-02-07T04:15:57.919+0000: [GC (Allocation Failure) [PSYoungGen: 232083K->14638K(240128K)] 249607K->32171KINFO:analyzer.shap.spark_shap_analyzer:_explain_dataframe finished, got 30162 local explanations
# INFO:analyzer.shap.spark_shap_analyzer:getting explanations took 49.87 seconds.
# INFO:analyzer.shap.spark_shap_analyzer:===================================================
# INFO:analyzer.shap.spark_shap_analyzer:converting explanations to tabular took 0.11 seconds.
# INFO:analyzer.shap.spark_shap_analyzer:===================================================
# INFO:analyzer.shap.spark_shap_analyzer:Writing local explanations to file:///opt/ml/processing/output/explanations_shap/out.csv
# INFO:analyzer.shap.spark_shap_analyzer:writing local explanations took 5.27 seconds.
# INFO:analyzer.shap.spark_shap_analyzer:===================================================
# INFO:analyzer.shap.spark_shap_analyzer:Wrote baseline to: /opt/ml/processing/output/explanations_shap/baseline.csv
# INFO:analyzer.shap.spark_shap_analyzer:converting explanations to tabular took 0.10 seconds.
# INFO:analyzer.shap.spark_shap_analyzer:===================================================
# INFO:analyzer.shap.global_aggregator:Aggregating global explanations
# 04:16:34.862 [Thread-6] WARN  o.a.spark.sql.catalyst.util.package - Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# INFO:analyzer.predictor:Stop using endpoint: sm-clarify-DEMO-clarify-model-07-02-2023-03-52--1675743156-c537
# INFO:sagemaker:Deleting endpoint configuration with name: sm-clarify-config-1675743155-c4e6
# INFO:sagemaker:Deleting endpoint with name: sm-clarify-DEMO-clarify-model-07-02-2023-03-52--1675743156-c537
# INFO:analyzer.predictor:Model endpoint delivered 0.01637 requests per second and a total of 1 requests over 61 seconds
# INFO:analyzer.predictor:Stop using endpoint: None
# 2023-02-07 04:16:39,197 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000003/launch_container.sh]
# 2023-02-07 04:16:39,197 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000003/container_tokens]
# 2023-02-07 04:16:39,197 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000003/sysfs]
# 2023-02-07 04:16:39,229 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000002/launch_container.sh]
# 2023-02-07 04:16:39,230 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000002/container_tokens]
# 2023-02-07 04:16:39,230 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000002/sysfs]
# 02-07 04:16 smspark-submit INFO     spark submit was successful. primary node exiting.
# 2023-02-07 04:16:39,586 smspark submit job is executed
# 2023-02-07 04:16:39,696 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000001/launch_container.sh]
# 2023-02-07 04:16:39,700 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000001/container_tokens]
# 2023-02-07 04:16:39,700 WARN org.apache.hadoop.yarn.server.nodemanager.DefaultContainerExecutor: delete returned false for path: [/tmp/hadoop-root/nm-local-dir/usercache/root/appcache/application_1675743111931_0001/container_1675743111931_0001_01_000001/sysfs]
# 2023-02-07 04:16:39,701 INFO org.apache.hadoop.yarn.server.resourcemanager.RMAppManager$ApplicationSummary: appId=application_1675743111931_0001,name=analyzer,user=root,queue=default,state=FINISHED,trackingUrl=http://algo-1:8088/proxy/application_1675743111931_0001/,appMasterHost=10.0.104.48,submitTime=1675743131347,startTime=1675743131440,launchTime=1675743132647,finishTime=1675743399185,finalStatus=SUCCEEDED,memorySeconds=7296843,vcoreSeconds=784,preemptedMemorySeconds=0,preemptedVcoreSeconds=0,preemptedAMContainers=0,preemptedNonAMContainers=0,preemptedResources=<memory:0\, vCores:0>,applicationType=SPARK,resourceSeconds=7296843 MB-seconds\, 784 vcore-seconds,preemptedResourceSeconds=0 MB-seconds\, 0 vcore-seconds,applicationTags=
# 2023-02-07 04:16:39,746 INFO SecurityLogger.org.apache.hadoop.ipc.Server: Auth successful for appattempt_1675743111931_0001_000001 (auth:SIMPLE)
# 2023-02-07 04:16:39,845 Unable to display local shap values, no features found
# 2023-02-07 04:16:39,852 ['jupyter', 'nbconvert', '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 316718 bytes to /opt/ml/processing/output/report.html
# 2023-02-07 04:16:40,782 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2023-02-07 04:16:41,321 Collected analyses:
# {
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "expected_value": 0.00258383946493268,
#                 "global_shap_values": {
#                     "Age": 0.023696499897432218,
#                     "Capital Gain": 0.07505199379218276,
#                     "Capital Loss": 0.02228261699273224,
#                     "Country": 0.04775662091338265,
#                     "Education": 0.018109927082466604,
#                     "Education-Num": 0.026715555677987595,
#                     "Ethnic group": 0.016736992435520265,
#                     "Hours per week": 0.020952449683338266,
#                     "Marital Status": 0.026392813524523558,
#                     "Occupation": 0.028075676097598357,
#                     "Relationship": 0.03460077390420901,
#                     "Sex": 0.018173542853692118,
#                     "Workclass": 0.018049724902804192,
#                     "fnlwgt": 0.021055380884656277
#                 }
#             }
#         }
#     },
#     "version": "1.0"
# }
# 2023-02-07 04:16:41,321 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# 02-07 04:16 urllib3.connectionpool WARNING  Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa9907902e0>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:16 urllib3.connectionpool WARNING  Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa990790bb0>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 2023-02-07 04:16:44,676 WARN org.apache.hadoop.hdfs.server.datanode.DataNode: IOException in offerService
# java.io.EOFException: End of File Exception between local host is: "algo-2/10.0.122.113"; destination host is: "algo-1":8020; : java.io.EOFException; For more details see:  http://wiki.apache.org/hadoop/EOFException
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# #011at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# #011at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# #011at org.apache.hadoop.net.NetUtils.wrapWithMessage(NetUtils.java:833)
# #011at org.apache.hadoop.net.NetUtils.wrapException(NetUtils.java:791)
# #011at org.apache.hadoop.ipc.Client.getRpcResponse(Client.java:1549)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1491)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1388)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:233)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:118)
# #011at com.sun.proxy.$Proxy16.sendHeartbeat(Unknown Source)
# #011at org.apache.hadoop.hdfs.protocolPB.DatanodeProtocolClientSideTranslatorPB.sendHeartbeat(DatanodeProtocolClientSideTranslatorPB.java:168)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.sendHeartBeat(BPServiceActor.java:517)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.offerService(BPServiceActor.java:648)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.run(BPServiceActor.java:849)
# #011at java.lang.Thread.run(Thread.java:750)
# Caused by: java.io.EOFException
# #011at java.io.DataInputStream.readInt(DataInputStream.java:392)
# #011at org.apache.hadoop.ipc.Client$IpcStreams.readResponse(Client.java:1850)
# #011at org.apache.hadoop.ipc.Client$Connection.receiveRpcResponse(Client.java:1183)
# #011at org.apache.hadoop.ipc.Client$Connection.run(Client.java:1079)
# 02-07 04:16 urllib3.connectionpool WARNING  Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa990790040>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:16 urllib3.connectionpool WARNING  Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa9907ba1c0>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:16 urllib3.connectionpool WARNING  Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa9907ba3d0>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# 02-07 04:16 smspark-submit INFO     primary is down, worker now exiting
# 2023-02-07 04:16:57,363 smspark submit job is executed
# 2023-02-07 04:16:57,364 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# 2023-02-07 04:16:57,681 WARN org.apache.hadoop.hdfs.server.datanode.DataNode: IOException in offerService
# java.net.ConnectException: Call From algo-2/10.0.122.113 to algo-1:8020 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# #011at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# #011at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# #011at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# #011at org.apache.hadoop.net.NetUtils.wrapWithMessage(NetUtils.java:833)
# #011at org.apache.hadoop.net.NetUtils.wrapException(NetUtils.java:757)
# #011at org.apache.hadoop.ipc.Client.getRpcResponse(Client.java:1549)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1491)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1388)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:233)
# #011at org.apache.hadoop.ipc.ProtobufRpcEngine$Invoker.invoke(ProtobufRpcEngine.java:118)
# #011at com.sun.proxy.$Proxy16.sendHeartbeat(Unknown Source)
# #011at org.apache.hadoop.hdfs.protocolPB.DatanodeProtocolClientSideTranslatorPB.sendHeartbeat(DatanodeProtocolClientSideTranslatorPB.java:168)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.sendHeartBeat(BPServiceActor.java:517)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.offerService(BPServiceActor.java:648)
# #011at org.apache.hadoop.hdfs.server.datanode.BPServiceActor.run(BPServiceActor.java:849)
# #011at java.lang.Thread.run(Thread.java:750)
# Caused by: java.net.ConnectException: Connection refused
# #011at sun.nio.ch.SocketChannelImpl.checkConnect(Native Method)
# #011at sun.nio.ch.SocketChannelImpl.finishConnect(SocketChannelImpl.java:716)
# #011at org.apache.hadoop.net.SocketIOWithTimeout.connect(SocketIOWithTimeout.java:206)
# #011at org.apache.hadoop.net.NetUtils.connect(NetUtils.java:533)
# #011at org.apache.hadoop.ipc.Client$Connection.setupConnection(Client.java:700)
# #011at org.apache.hadoop.ipc.Client$Connection.setupIOstreams(Client.java:804)
# #011at org.apache.hadoop.ipc.Client$Connection.access$3800(Client.java:421)
# #011at org.apache.hadoop.ipc.Client.getConnection(Client.java:1606)
# #011at org.apache.hadoop.ipc.Client.call(Client.java:1435)
# #011... 9 more
# [/var/log/yarn/userlogs/application_1675743111931_0001/container_1675743111931_0001_01_000003/stdout] 2023-02-07T04:15:38.519+0000: [GC (Allocation Failure) [PSYoungGen: 248810K->16877K(251392K)] 266231K->34772K(

# %% [markdown]
# #### Viewing the Explainability Report
# As with the bias report, you can view the explainability report in Studio under the experiments tab
#
#
# <img src="./recordings/explainability_detail.gif">
#
# The Model Insights tab contains direct links to the report and model insights.
#
# If you're not a Studio user yet, as with the Bias Report, you can access this report at the following S3 bucket.

# %%
explainability_output_path
# Out:
# 's3://sagemaker-us-west-2-000000000000/sagemaker/DEMO-sagemaker-clarify/clarify-explainability'

# %% [markdown]
# #### Analysis of local explanations
# It is possible to visualize the the local explanations for single examples in your dataset. You can use the obtained results from running Kernel SHAP algorithm for global explanations.

# %%
analysis_result_json = sagemaker.s3.S3Downloader.read_file(
    explainability_output_path + "/analysis.json"
)
analysis_result = json.loads(analysis_result_json)
shap_values = analysis_result["explanations"]["kernel_shap"]["label0"]["global_shap_values"]
features = pd.Series(shap_values)
feature_names = features.index
feature_names
# Out:
# Index(['Age', 'Capital Gain', 'Capital Loss', 'Country', 'Education',
#        'Education-Num', 'Ethnic group', 'Hours per week', 'Marital Status',
#        'Occupation', 'Relationship', 'Sex', 'Workclass', 'fnlwgt'],
#       dtype='object')

# %% [markdown]
# With Clarify Spark jobs, the output files that contain local SHAP values will be split into multiple files. You will need to collate them before you can visualize them.

# %%
_s3 = boto3.resource("s3")
my_bucket = _s3.Bucket(bucket)
s3_files = [
    "s3://{}/{}".format(obj.bucket_name, obj.key)
    for obj in my_bucket.objects.filter(
        Prefix=prefix + "/clarify-explainability/explanations_shap/out.csv/"
    )
    if obj.key.endswith(".csv")
]
print(f"Found {len(s3_files)} files in S3")
# Out:
# Found 128 files in S3

# %%
# For the sake of time, open a subset of the s3 files
num_files_to_open = len(s3_files)
local_shap_values = pd.DataFrame()
for file in s3_files[:num_files_to_open]:
    output = sagemaker.s3.S3Downloader.read_file(file)
    df = pd.read_csv(StringIO(output), sep=",")
    local_shap_values = local_shap_values.append(df, ignore_index=True)

# %% [markdown]
# #### Visualize local SHAP values

# %%
max_features_to_display = 15
feature_names = local_shap_values.columns

fig = plt.figure(figsize=(max_features_to_display, max_features_to_display))
low = local_shap_values.min().min()
high = local_shap_values.max().max()

i = 1
for feature_name in feature_names:
    plt.subplot(max_features_to_display, 1, i)
    shap_value = local_shap_values[f"{feature_name}"].to_frame()
    feature = pd.Series([feature_name] * shap_value.shape[0]).to_frame()
    df = pd.concat([shap_value, feature], axis=1, join="inner", ignore_index=True)
    df.columns = ["shap_value", "feature"]
    num_rows_to_display = min(df.shape[0], 500)
    df = df.sample(num_rows_to_display)
    ax = sns.violinplot(
        y="feature",
        x="shap_value",
        data=df,
        size=6,
        color="#f5f5f5",
        inner="quartile",
        bw=0.2,
        cut=0,
        orient="h",
    )
    ax.set_xlim(low, high)
    sns.stripplot(
        y="feature",
        x="shap_value",
        data=df,
        size=4,
        orient="h",
    )
    ax.vlines(0, -1, 1, color="#ff0000", linewidth=2)
    ax.set_ylabel("")
    ax.legend([], [], frameon=False)
    i += 1


plt.xlabel("Local SHAP Values", fontsize=14)
plt.tight_layout()
plt.subplots_adjust(hspace=0, wspace=0.1)

plt.show()

# %% [markdown]
# ### Clean Up
# Finally, don't forget to clean up the resources we set up and used for this demo!

# %%
sagemaker_session.delete_model(model_name)
# Out:
# INFO:sagemaker:Deleting model with name: DEMO-clarify-model-07-02-2023-03-52-02

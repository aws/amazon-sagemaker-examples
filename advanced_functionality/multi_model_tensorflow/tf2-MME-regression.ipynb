# %% [markdown]
# # Amazon SageMaker Multi-Model Endpoints using TensorFlow

# %% [markdown]
# ## Prerequisites (Please Read Cell Below)

# %% [markdown]
# With Amazon SageMaker [multi-model endpoints](https://docs.aws.amazon.com/sagemaker/latest/dg/multi-model-endpoints.html), customers can create an endpoint that seamlessly hosts up to thousands of models. These endpoints are well suited to use cases where any one of a large number of models, which can be served from a common inference container, needs to be invokable on-demand and where it is acceptable for infrequently invoked models to incur some additional latency. For applications which require consistently low inference latency, a traditional endpoint is still the best choice.
#
# To demonstrate how multi-model endpoints can be created and used, this notebook provides an example using models trained with the [SageMaker TensorFlow framework container](https://github.com/aws/sagemaker-tensorflow-serving-container/tree/dc1ccd1cb19114a0b357862aa2177e9d2a67fdf5).
#
# We'll train and deploy two different TensorFlow ANN Models for Boston Housing and [Petrol Consumption](https://www.kaggle.com/harinir/petrol-consumption) datasets. The first portion will cover Boston Housing Steps and then repeat same procedure for the Petrol dataset with its own training script/model.
#
# For other MME use cases, you can also refer to:
#
# Segmented home value modelling examples with the [PyTorch framework](https://github.com/aws/amazon-sagemaker-examples/blob/master/advanced_functionality/multi_model_pytorch/pytorch_multi_model_endpoint.ipynb), [Scikit-Learn framework](https://github.com/aws/amazon-sagemaker-examples/tree/master/advanced_functionality/multi_model_sklearn_home_value), the [XGBoost pre-built algorithm](https://github.com/aws/amazon-sagemaker-examples/tree/master/advanced_functionality/multi_model_xgboost_home_value), and the [Linear Learner algorithm](https://github.com/aws/amazon-sagemaker-examples/tree/master/advanced_functionality/multi_model_linear_learner_home_value).
# An example with [MXNet](https://github.com/aws/amazon-sagemaker-examples/tree/master/advanced_functionality/multi_model_bring_your_own) and corresponding [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/build-multi-model-build-container.html) on how to use MME with your own custom containers.
#
# **Kernel**: conda_tensorflow2_p36

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import boto3
import sagemaker
import os
from sagemaker.tensorflow import TensorFlow
from sagemaker.inputs import TrainingInput
from sagemaker import get_execution_role
from sagemaker.tensorflow.serving import TensorFlowModel
from sagemaker.multidatamodel import MultiDataModel

# %% [markdown]
# ## Role and S3 Buckets

# %%
role = get_execution_role()
session = boto3.Session()
sagemaker_session = sagemaker.Session()

s3 = session.resource('s3')
TF_FRAMEWORK_VERSION = '2.3.0'
BUCKET = sagemaker.Session().default_bucket()
PREFIX = 'regression-models'

# %% [markdown]
# # Boston Housing Model Training

# %% [markdown]
# ## Boston Dataset Creation

# %%
from sklearn import datasets #Boston Housing
boston = datasets.load_boston()
X = pd.DataFrame(boston.data, columns=boston.feature_names)
y = pd.DataFrame(boston.target)
y.columns=['TARGET']
df = pd.concat([X,y], axis=1)

#split into train and test to push to local
bostonTrain = df.iloc[:450,:]
bostonTest = df.iloc[451:,:]

# %%
DATASET_PATH = './Data/Boston'
os.makedirs(DATASET_PATH, exist_ok=True)

# %%
bostonTrain.to_csv('Data/Boston/train.csv', index=False)
bostonTest.to_csv('Data/Boston/test.csv', index=False)

# %%
# !aws s3 cp ./{DATASET_PATH}/train.csv s3://{BUCKET}/{PREFIX}/BostonHousing/train/
# Out:
# upload: Data/Boston/train.csv to s3://sagemaker-us-east-1-474422712127/regression-models/BostonHousing/train/train.csv

# %% [markdown]
# ## Create Training Inputs Boston Model

# %%
train_input = TrainingInput(s3_data=f's3://{BUCKET}/{PREFIX}/BostonHousing/train',content_type='csv')

# %%
inputs = {'train': train_input}

# %% [markdown]
# ## Boston Model Training

# %%
model_name = 'bostonhousing-ann'
hyperparameters = {'epochs': 50}
estimator_parameters = {'source_dir':"Scripts",
                        'entry_point':'boston.py',
                        'instance_type': 'ml.m5.2xlarge',
                        'instance_count': 1,
                        'model_dir': f'/opt/ml/model',
                        'role': role,
                        'hyperparameters': hyperparameters,
                        'output_path': f's3://{BUCKET}/{PREFIX}/BostonHousing/out',
                        'base_job_name': f'mme-cv-{model_name}',
                        'framework_version': TF_FRAMEWORK_VERSION,
                        'py_version': 'py37',
                        'script_mode': True}
estimator_1 = TensorFlow(**estimator_parameters)
estimator_1.fit(inputs)
# Out:
# 2021-08-23 01:53:23 Starting - Starting the training job...
# 2021-08-23 01:53:25 Starting - Launching requested ML instancesProfilerReport-1629683602: InProgress
# ...
# 2021-08-23 01:54:18 Starting - Preparing the instances for training......
# 2021-08-23 01:55:23 Downloading - Downloading input data...
# 2021-08-23 01:55:47 Training - Downloading the training image.....2021-08-23 01:56:30,242 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-08-23 01:56:30,249 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 01:56:30,590 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 01:56:30,605 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 01:56:30,619 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 01:56:30,629 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "/opt/ml/model",
#         "epochs": 50
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "mme-cv-bostonhousing-ann-2021-08-23-01-53-22-813",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-474422712127/mme-cv-bostonhousing-ann-2021-08-23-01-53-22-813/source/sourcedir.tar.gz",
#     "module_name": "boston",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "boston.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":50,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=boston.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=boston
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-474422712127/mme-cv-bostonhousing-ann-2021-08-23-01-53-22-813/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":50,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"mme-cv-bostonhousing-ann-2021-08-23-01-53-22-813","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-474422712127/mme-cv-bostonhousing-ann-2021-08-23-01-53-22-813/source/sourcedir.tar.gz","module_name":"boston","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"boston.py"}
# SM_USER_ARGS=["--epochs","50","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=50
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 boston.py --epochs 50 --model_dir /opt/ml/model
#
#
# reading
# read
# [2021-08-23 01:56:33.210 ip-10-2-239-206.ec2.internal:25 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-08-23 01:56:33.210 ip-10-2-239-206.ec2.internal:25 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-08-23 01:56:33.210 ip-10-2-239-206.ec2.internal:25 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2021-08-23 01:56:33.210 ip-10-2-239-206.ec2.internal:25 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-08-23 01:56:33.311 ip-10-2-239-206.ec2.internal:25 INFO hook.py:398] Monitoring the collections: sm_metrics, metrics, losses
# Epoch 1/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 1563.7114#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 7/12 [================>.............] - ETA: 0s - loss: 1530.3566#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - ETA: 0s - loss: 1359.2500#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 28ms/step - loss: 1359.2500 - val_loss: 928.7784
# Epoch 2/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 950.8362#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 742.6638 - val_loss: 398.5838
# Epoch 3/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 382.9047#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 279.8925 - val_loss: 244.8390
# Epoch 4/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 248.9976#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01511/12 [==========================>...] - ETA: 0s - loss: 145.1087#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 8ms/step - loss: 142.4958 - val_loss: 112.4135
# Epoch 5/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 103.4216#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 96.3245 - val_loss: 98.9117
# Epoch 6/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 76.4601#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 85.2203 - val_loss: 88.2754
# Epoch 7/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 86.9530#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01510/12 [========================>.....] - ETA: 0s - loss: 78.3877#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 8ms/step - loss: 80.4602 - val_loss: 76.5218
# Epoch 8/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 57.8609#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 75.5489 - val_loss: 74.6961
# Epoch 9/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 117.7491#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 5ms/step - loss: 73.3060 - val_loss: 67.9950
# Epoch 10/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 57.4128#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 72.5247 - val_loss: 64.9841
# Epoch 11/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 87.2385#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 70.4704 - val_loss: 62.8356
# Epoch 12/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 61.8006#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 69.2424 - val_loss: 61.4397
# Epoch 13/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 22.3508#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 67.5638 - val_loss: 60.1380
# Epoch 14/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 64.1211#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 67.4238 - val_loss: 57.3746
# Epoch 15/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 25.8521#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 67.6608 - val_loss: 57.6294
# Epoch 16/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 52.8020#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 66.5061 - val_loss: 56.6178
# Epoch 17/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 64.3730#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 66.0683 - val_loss: 55.7667
# Epoch 18/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 35.8981#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 65.0046 - val_loss: 55.5992
# Epoch 19/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 101.0478#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 64.6765 - val_loss: 54.7843
# Epoch 20/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 52.0128#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 62.9437 - val_loss: 56.0827
# Epoch 21/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 46.4495#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 62.5932 - val_loss: 55.2374
# Epoch 22/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 55.8624#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 62.4966 - val_loss: 53.9700
# Epoch 23/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 32.7840#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 60.4683 - val_loss: 54.9084
# Epoch 24/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 43.6985#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 60.2755 - val_loss: 51.7536
# Epoch 25/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 41.5039#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 8ms/step - loss: 59.6334 - val_loss: 54.2677
# Epoch 26/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 26.8312#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 60.0258 - val_loss: 53.9408
# Epoch 27/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 78.4598#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 58.3514 - val_loss: 51.7361
# Epoch 28/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 133.3623#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01511/12 [==========================>...] - ETA: 0s - loss: 57.7516 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 8ms/step - loss: 57.8264 - val_loss: 51.1698
# Epoch 29/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 126.5016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 57.0232 - val_loss: 51.8706
# Epoch 30/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 29.7083#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 56.8363 - val_loss: 52.6230
# Epoch 31/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 77.4052#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01510/12 [========================>.....] - ETA: 0s - loss: 54.3033#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 9ms/step - loss: 58.2359 - val_loss: 51.5804
# Epoch 32/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 26.7945#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 56.6030 - val_loss: 53.2394
# Epoch 33/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 54.5917#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 55.5643 - val_loss: 52.2720
# Epoch 34/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 106.3591#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 54.8035 - val_loss: 49.0654
# Epoch 35/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 17.5574#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 54.9361 - val_loss: 54.0415
# Epoch 36/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 64.9337#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 53.6610 - val_loss: 49.6197
# Epoch 37/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 60.1063#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 53.0934 - val_loss: 52.0326
# Epoch 38/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 45.0551#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 52.5959 - val_loss: 48.7558
# Epoch 39/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 65.1016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 52.6821 - val_loss: 50.7533
# Epoch 40/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 41.6100#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 51.7925 - val_loss: 48.3618
# Epoch 41/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 27.5799#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 51.6978 - val_loss: 48.1835
# Epoch 42/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 51.3154#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 50.5955 - val_loss: 49.4345
# Epoch 43/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 38.1963#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - ETA: 0s - loss: 50.4809#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 15ms/step - loss: 50.4809 - val_loss: 46.6282
# Epoch 44/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 45.9757#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 49.6540 - val_loss: 50.0837
# Epoch 45/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 29.3376#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 49.8692 - val_loss: 45.6657
# Epoch 46/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 87.1264#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 49.3616 - val_loss: 48.3577
# Epoch 47/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 48.6157#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 48.7127 - val_loss: 44.2963
# Epoch 48/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 59.9415#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 50.3413 - val_loss: 44.0182
# Epoch 49/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 76.2934#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 48.8551 - val_loss: 47.4711
# Epoch 50/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 50.9466#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 47.1391 - val_loss: 44.0340
# Saving model
# 2021-08-23 01:56:39,462 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-08-23 01:56:51 Uploading - Uploading generated training model
# 2021-08-23 01:56:51 Completed - Training job completed
# Training seconds: 88
# Billable seconds: 88

# %% [markdown]
# ## Create Boston Model

# %%
model_1 = estimator_1.create_model(role=role, source_dir="Scripts", entry_point="inference.py")

# %% [markdown]
# ## Create Boston Endpoint

# %%
predictorA = model_1.deploy(
    initial_instance_count=1,
    instance_type="ml.c5.xlarge",
)
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ----!

# %% [markdown]
# ## Test Boston Endpoint Individually

# %% [markdown]
# Test both endpoints individually just to make sure both are working.

# %%
predictorA.serializer = sagemaker.serializers.JSONSerializer()
predictorA.deserializer = sagemaker.deserializers.JSONDeserializer()

# %%
#Grab sample test data
test = pd.read_csv('/home/ec2-user/SageMaker/TensorFlow-MME/Data/Boston/train.csv')
test[:1]
testX = test.drop("TARGET", axis=1)
testX = testX[:1].values.tolist()
sampInput = {"inputs": testX}
sampInput
# Out:
# {'inputs': [[0.00632,
#    18.0,
#    2.31,
#    0.0,
#    0.5379999999999999,
#    6.575,
#    65.2,
#    4.09,
#    1.0,
#    296.0,
#    15.3,
#    396.9,
#    4.98]]}

# %%
predicted_value = predictorA.predict(sampInput)
predicted_value
# Out:
# {'outputs': [[27.7003841]]}

# %% [markdown]
# ## Boto3 Invocation

# %%
import boto3
import json
from sagemaker.serializers import JSONSerializer

runtime_sm_client = boto3.client(service_name='sagemaker-runtime')
endpoint_name = predictorA.endpoint_name
jsons = JSONSerializer()
payload = jsons.serialize(sampInput)
response = runtime_sm_client.invoke_endpoint(
        EndpointName=endpoint_name,
        Body=payload)
result = json.loads(response['Body'].read().decode())['outputs']
result
# Out:
# [[26.1025639], [26.1895218]]

# %% [markdown]
# ## Delete Endpoint

# %%
predictorA.delete_endpoint(delete_endpoint_config=True)

# %% [markdown]
# # Petrol Housing Dataset Training
#
# Repeating same process as Boston Housing Model

# %%
petrolDF = pd.read_csv("petrol_consumption.csv")
petrolTrain = petrolDF.iloc[:35,:]
petrolTest = petrolDF.iloc[36:,:]
DATASET_PATH = './Data/Petrol'
os.makedirs(DATASET_PATH, exist_ok=True)
petrolTrain.to_csv('Data/Petrol/train.csv', index=False)
petrolTest.to_csv('Data/Petrol/test.csv', index=False)

# %%
# !aws s3 cp ./{DATASET_PATH}/train.csv s3://{BUCKET}/{PREFIX}/Petrol/train/
# Out:
# upload: Data/Petrol/train.csv to s3://sagemaker-us-east-1-474422712127/regression-models/Petrol/train/train.csv

# %%
train_input = TrainingInput(s3_data=f's3://{BUCKET}/{PREFIX}/Petrol/train',content_type='csv')

# %%
inputs = {'train': train_input}

# %% [markdown]
# ## Petrol Model Training

# %%
model_name = 'petrol-ann'
hyperparameters = {'epochs': 50}
estimator_parameters = {'source_dir':"Scripts",
                        'entry_point':'petrol.py',
                        'instance_type': 'ml.m5.2xlarge',
                        'instance_count': 1,
                        'model_dir': f'/opt/ml/model',
                        'role': role,
                        'hyperparameters': hyperparameters,
                        'output_path': f's3://{BUCKET}/{PREFIX}/Petrol/out',
                        'base_job_name': f'mme-cv-{model_name}',
                        'framework_version': TF_FRAMEWORK_VERSION,
                        'py_version': 'py37',
                        'script_mode': True}
estimator_2 = TensorFlow(**estimator_parameters)
estimator_2.fit(inputs)
# Out:
# 2021-08-23 02:04:00 Starting - Starting the training job...
# 2021-08-23 02:04:23 Starting - Launching requested ML instancesProfilerReport-1629684240: InProgress
# ...
# 2021-08-23 02:04:56 Starting - Preparing the instances for training.........
# 2021-08-23 02:06:23 Downloading - Downloading input data...
# 2021-08-23 02:06:54 Training - Downloading the training image...
# 2021-08-23 02:07:25 Uploading - Uploading generated training model2021-08-23 02:07:16,313 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-08-23 02:07:16,321 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 02:07:16,903 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 02:07:16,919 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 02:07:16,934 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-23 02:07:16,945 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "/opt/ml/model",
#         "epochs": 50
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "mme-cv-petrol-ann-2021-08-23-02-04-00-101",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-474422712127/mme-cv-petrol-ann-2021-08-23-02-04-00-101/source/sourcedir.tar.gz",
#     "module_name": "petrol",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "petrol.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":50,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=petrol.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=petrol
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-474422712127/mme-cv-petrol-ann-2021-08-23-02-04-00-101/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":50,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"mme-cv-petrol-ann-2021-08-23-02-04-00-101","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-474422712127/mme-cv-petrol-ann-2021-08-23-02-04-00-101/source/sourcedir.tar.gz","module_name":"petrol","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"petrol.py"}
# SM_USER_ARGS=["--epochs","50","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=50
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 petrol.py --epochs 50 --model_dir /opt/ml/model
#
#
# reading
# read
# [2021-08-23 02:07:19.887 ip-10-0-157-130.ec2.internal:25 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-08-23 02:07:19.887 ip-10-0-157-130.ec2.internal:25 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-08-23 02:07:19.887 ip-10-0-157-130.ec2.internal:25 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2021-08-23 02:07:19.887 ip-10-0-157-130.ec2.internal:25 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-08-23 02:07:20.172 ip-10-0-157-130.ec2.internal:25 INFO hook.py:398] Monitoring the collections: sm_metrics, metrics, losses
# Epoch 1/50
# #0151/1 [==============================] - ETA: 0s - loss: 167694.2188#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 214ms/step - loss: 167694.2188 - batch: 0.0000e+00 - val_loss: 124519.8047 - val_batch: 0.0000e+00
# Epoch 2/50
# #0151/1 [==============================] - ETA: 0s - loss: 151704.0781#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 151704.0781 - val_loss: 112397.6328
# Epoch 3/50
# #0151/1 [==============================] - ETA: 0s - loss: 136717.1250#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 54ms/step - loss: 136717.1250 - val_loss: 97820.4219
# Epoch 4/50
# #0151/1 [==============================] - ETA: 0s - loss: 121365.2656#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 37ms/step - loss: 121365.2656 - val_loss: 83071.0625
# Epoch 5/50
# #0151/1 [==============================] - ETA: 0s - loss: 105742.1250#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 49ms/step - loss: 105742.1250 - val_loss: 69633.7422
# Epoch 6/50
# #0151/1 [==============================] - ETA: 0s - loss: 91549.6172#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 91549.6172 - val_loss: 57667.7578
# Epoch 7/50
# #0151/1 [==============================] - ETA: 0s - loss: 78557.9922#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 78557.9922 - val_loss: 47186.8398
# Epoch 8/50
# #0151/1 [==============================] - ETA: 0s - loss: 66355.6797#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 37ms/step - loss: 66355.6797 - val_loss: 38157.7539
# Epoch 9/50
# #0151/1 [==============================] - ETA: 0s - loss: 56738.2422#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 56738.2422 - val_loss: 30564.9023
# Epoch 10/50
# #0151/1 [==============================] - ETA: 0s - loss: 50222.0195#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 37ms/step - loss: 50222.0195 - val_loss: 25015.4824
# Epoch 11/50
# #0151/1 [==============================] - ETA: 0s - loss: 45987.4023#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 45987.4023 - val_loss: 22004.4062
# Epoch 12/50
# #0151/1 [==============================] - ETA: 0s - loss: 43930.6758#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 43930.6758 - val_loss: 20376.1055
# Epoch 13/50
# #0151/1 [==============================] - ETA: 0s - loss: 43646.3320#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 43646.3320 - val_loss: 18989.9121
# Epoch 14/50
# #0151/1 [==============================] - ETA: 0s - loss: 42369.0898#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 34ms/step - loss: 42369.0898 - val_loss: 17717.0918
# Epoch 15/50
# #0151/1 [==============================] - ETA: 0s - loss: 39573.6875#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 39573.6875 - val_loss: 16505.5742
# Epoch 16/50
# #0151/1 [==============================] - ETA: 0s - loss: 35452.0781#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 37ms/step - loss: 35452.0781 - val_loss: 15615.0703
# Epoch 17/50
# #0151/1 [==============================] - ETA: 0s - loss: 30805.6250#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 30805.6250 - val_loss: 15312.7354
# Epoch 18/50
# #0151/1 [==============================] - ETA: 0s - loss: 26364.5742#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 26364.5742 - val_loss: 15898.9131
# Epoch 19/50
# #0151/1 [==============================] - ETA: 0s - loss: 23060.8965#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 23060.8965 - val_loss: 16088.6611
# Epoch 20/50
# #0151/1 [==============================] - ETA: 0s - loss: 20919.6934#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 37ms/step - loss: 20919.6934 - val_loss: 16633.4980
# Epoch 21/50
# #0151/1 [==============================] - ETA: 0s - loss: 20869.2344#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 20869.2344 - val_loss: 17206.4219
# Epoch 22/50
# #0151/1 [==============================] - ETA: 0s - loss: 22017.2148#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 22017.2148 - val_loss: 17557.0508
# Epoch 23/50
# #0151/1 [==============================] - ETA: 0s - loss: 22944.9688#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 44ms/step - loss: 22944.9688 - val_loss: 17508.2148
# Epoch 24/50
# #0151/1 [==============================] - ETA: 0s - loss: 23069.2051#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 23069.2051 - val_loss: 17152.5039
# Epoch 25/50
# #0151/1 [==============================] - ETA: 0s - loss: 22230.8125#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 22230.8125 - val_loss: 16655.8945
# Epoch 26/50
# #0151/1 [==============================] - ETA: 0s - loss: 20814.1387#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 20814.1387 - val_loss: 16288.9346
# Epoch 27/50
# #0151/1 [==============================] - ETA: 0s - loss: 19292.1973#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 19292.1973 - val_loss: 16240.1709
# Epoch 28/50
# #0151/1 [==============================] - ETA: 0s - loss: 17982.0059#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 35ms/step - loss: 17982.0059 - val_loss: 16409.8750
# Epoch 29/50
# #0151/1 [==============================] - ETA: 0s - loss: 17393.5879#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 34ms/step - loss: 17393.5879 - val_loss: 16535.3438
# Epoch 30/50
# #0151/1 [==============================] - ETA: 0s - loss: 17786.1055#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 34ms/step - loss: 17786.1055 - val_loss: 16624.3867
# Epoch 31/50
# #0151/1 [==============================] - ETA: 0s - loss: 18540.9883#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 36ms/step - loss: 18540.9883 - val_loss: 16814.2266
# Epoch 32/50
# #0151/1 [==============================] - ETA: 0s - loss: 19100.2148#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0151/1 [==============================] - 0s 37ms/step - loss: 19100.2148 - val_loss: 16955.9258
# Saving model
# 2021-08-23 02:07:23,684 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-08-23 02:07:44 Completed - Training job completed
# Training seconds: 76
# Billable seconds: 76

# %% [markdown]
# ## Create Petrol Model

# %%
model_2 = estimator_2.create_model(role=role, source_dir="Scripts", entry_point="inference.py")

# %% [markdown]
# ## Petrol Endpoint Creation

# %%
predictorB = model_2.deploy(
    initial_instance_count=1,
    instance_type="ml.c5.xlarge",
)
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# -----------!

# %% [markdown]
# ## Test Petrol Endpoint

# %%
predictorB.serializer = sagemaker.serializers.JSONSerializer()
predictorB.deserializer = sagemaker.deserializers.JSONDeserializer()

# %%
test = pd.read_csv('/home/ec2-user/SageMaker/TensorFlow-MME/Data/Petrol/train.csv')
test[:1]
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
#
#    Petrol_Consumption
# 0                 541

# %%
testX = test.drop("Petrol_Consumption", axis=1)
testX = testX[:1].values.tolist()
sampInput = {"inputs": testX}
sampInput
# Out:
# {'inputs': [[9.0, 3571.0, 1976.0, 0.525]]}

# %%
predicted_value = predictorB.predict(sampInput)
predicted_value
# Out:
# {'outputs': [[417.224182]]}

# %% [markdown]
# ## Boto3 Petrol Endpoint Test

# %%
import boto3
import json
from sagemaker.serializers import JSONSerializer

runtime_sm_client = boto3.client(service_name='sagemaker-runtime')
endpoint_name = predictorB.endpoint_name
jsons = JSONSerializer()
payload = jsons.serialize(sampInput)
response = runtime_sm_client.invoke_endpoint(
        EndpointName=endpoint_name,
        Body=payload)
result = json.loads(response['Body'].read().decode())['outputs']
result
# Out:
# [[417.224182]]

# %% [markdown]
# ## Delete Petrol Endpoint

# %%
predictorB.delete_endpoint(delete_endpoint_config=True)

# %% [markdown]
# # Multi Model Endpoint Creation

# %% [markdown]
# ## MME S3 Model Path

# %%
tf_model_1 = estimator_1.model_data
output_1 = f's3://{BUCKET}/{PREFIX}/mme/boston.tar.gz'

tf_model_2 = estimator_2.model_data
output_2 = f's3://{BUCKET}/{PREFIX}/mme/petrol.tar.gz'

# %%
# !aws s3 cp {tf_model_1} {output_1}
# !aws s3 cp {tf_model_2} {output_2}
# Out:
# copy: s3://sagemaker-us-east-1-474422712127/regression-models/BostonHousing/out/mme-cv-bostonhousing-ann-2021-08-23-01-53-22-813/output/model.tar.gz to s3://sagemaker-us-east-1-474422712127/regression-models/mme/boston.tar.gz
# copy: s3://sagemaker-us-east-1-474422712127/regression-models/Petrol/out/mme-cv-petrol-ann-2021-08-23-02-04-00-101/output/model.tar.gz to s3://sagemaker-us-east-1-474422712127/regression-models/mme/petrol.tar.gz

# %%
from datetime import datetime
import time
current_time = datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d-%H-%M-%S')
current_time
model_data_prefix = f's3://{BUCKET}/{PREFIX}/mme/'

# %% [markdown]
# ## Create Multi Data Model
#
# Can use model 1 or any model from estimators (in this case only 2) because MME operates in a shared container.

# %%
mme = MultiDataModel(name=f'mme-tensorflow-{current_time}',
                     model_data_prefix=model_data_prefix,
                     model=model_1,
                     sagemaker_session=sagemaker_session)

# %% [markdown]
# ## Check for Model Artifacts in MME Model Location

# %%
list(mme.list_models())
# Out:
# ['boston.tar.gz', 'petrol.tar.gz']

# %% [markdown]
# ## Create MME

# %%
predictor = mme.deploy(initial_instance_count=1,
                       instance_type='ml.m5.2xlarge',
                       endpoint_name=f'mme-tensorflow-{current_time}')
# Out:
# -----------!

# %% [markdown]
# ## Test MME Boston Model

# %%
test = pd.read_csv('/home/ec2-user/SageMaker/TensorFlow-MME/Data/Boston/train.csv')
test[:1]
testX = test.drop("TARGET", axis=1)
testX = testX[:2].values.tolist()
sampInput = {"inputs": testX}
sampInput
# Out:
# {'inputs': [[0.00632,
#    18.0,
#    2.31,
#    0.0,
#    0.5379999999999999,
#    6.575,
#    65.2,
#    4.09,
#    1.0,
#    296.0,
#    15.3,
#    396.9,
#    4.98],
#   [0.02731,
#    0.0,
#    7.07,
#    0.0,
#    0.469,
#    6.421,
#    78.9,
#    4.9671,
#    2.0,
#    242.0,
#    17.8,
#    396.9,
#    9.14]]}

# %%
y_pred = predictor.predict(data=sampInput, initial_args={'TargetModel': 'boston.tar.gz'})
y_pred
# Out:
# {'outputs': [[27.7003841], [25.4000874]]}

# %% [markdown]
# ## Test MME Petrol Model

# %%
test = pd.read_csv('/home/ec2-user/SageMaker/TensorFlow-MME/Data/Petrol/train.csv')
testX = test.drop("Petrol_Consumption", axis=1)
testX = testX[:2].values.tolist()
sampInput = {"inputs": testX}
sampInput
# Out:
# {'inputs': [[9.0, 3571.0, 1976.0, 0.525],
#   [9.0, 4092.0, 1250.0, 0.5720000000000001]]}

# %%
y_pred = predictor.predict(data=sampInput, initial_args={'TargetModel': 'petrol.tar.gz'})
y_pred
# Out:
# {'outputs': [[417.224182], [375.122925]]}

# %% [markdown]
# ## Boto3 MME Test

# %%
import boto3
import json
from sagemaker.serializers import JSONSerializer
endpoint_name = predictor.endpoint_name

##########
#Petrol Model
##########
target_model = "petrol.tar.gz"
jsons = JSONSerializer()
payload = jsons.serialize(sampInput)
response = runtime_sm_client.invoke_endpoint(
        EndpointName=endpoint_name,
        TargetModel=target_model,
        Body=payload)
result = json.loads(response['Body'].read().decode())['outputs']
result
# Out:
# [[417.224182], [375.122925]]

# %% [markdown]
# ## Delete Endpoint

# %%
predictor.delete_endpoint(delete_endpoint_config=True)
